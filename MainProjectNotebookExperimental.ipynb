# %% [markdown]
# # Reinforcement Learning in OpenAI

# %% [markdown]
# First, let's make sure we have the required modules installed, by running the following cell:

# %%
# !pip install gym
# !pip install tensorflow
# !pip install keras
# Out:
# Requirement already satisfied: gym in c:\users\surface\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in c:\users\surface\anaconda3\lib\site-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in c:\users\surface\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\surface\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\surface\anaconda3\lib\site-packages (from gym) (1.18.5)
# Requirement already satisfied: future in c:\users\surface\anaconda3\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# Requirement already satisfied: tensorflow in c:\users\surface\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: gast==0.3.3 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.22.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (49.2.0.post20200714)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\surface\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\surface\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\surface\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\surface\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\surface\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\surface\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\surface\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\surface\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\surface\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\surface\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\surface\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Collecting keras
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\surface\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\surface\anaconda3\lib\site-packages (from keras) (1.5.0)
# Requirement already satisfied: pyyaml in c:\users\surface\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in c:\users\surface\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in c:\users\surface\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %% [markdown]
# Now lets import the modules:

# %%
import gym
import math
import random
import time
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

# %% [markdown]
# Now, let's see how we can interact with the environment in OpenAI:

# %%
env_name = 'CartPole-v0'
env = gym.make(env_name)
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# Observation space: Box(4,)
# Action space: Discrete(2)

# %% [markdown]
# In OpenAI environments, the input we give our agents is taken from the Observation space. In this case, Box(4,) refers to a continuous space.
# If we go to the CartPole-v1 documentation:(https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)
# we can see the observation space gives us 4 continuous observation (input) options, and 2 discrete action (output) options.
#
# Now let's see how we can make a basic agent:

# %%
class RandomAgent():
    # create basicAgent class
    def __init__(self,env):
        # constructor
        self.action_size = env.action_space.n
        # number of available actions, in this case 2
        
    def get_action(self,state):
        # method for choosing action
        action = random.choice(range(self.action_size))
        # choose random action 
        return action

# %% [markdown]
# Now that we have a basic agent that returns a random action, lets run it:

# %%
agent = RandomAgent(env)
# create agent object
state = env.reset() 
# reset environment state and define initial state
total_reward = 0

for _ in range(100):
    # loop for 100 iterations
    action = agent.get_action(state)
    # get action from agent passing in the state
    state, reward, done, info = env.step(action)
    # returns the state after action (env object)
    # env.render()
    # time.sleep(0.03)
    if not done:
        total_reward += reward
env.close()
print("Reward: {}".format(total_reward))
# Out:
# Reward: 26.0
# C:\Users\surface\anaconda3\lib\site-packages\gym\logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# Each environment has its own "Solved" requirements, and some remain unsolved, as can be seen on the Leaderboard: https://github.com/openai/gym/wiki/Leaderboard
# For the CartPole-v1 env, "done" returns True when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center, and "solving" is defined as getting average reward of 195.0 over 100 consecutive trials.  A reward of +1 is provided for every timestep that the pole remains upright. Done also returns true when the reward is 200.
#
# Obviously, our random agent isn't performing that well. Let's try and improve on this by giving it a non-random policy and interacting with the observation space:

# %%
class BasicPolicyAgent():
    def __init__(self,env):
        self.action_size = env.action_space.n
    def get_action(self, state):
        pole_angle = state[2]
        # index[2] of observation space
        action = 0 if pole_angle < 0 else 1
        # policy action, move left is angle < 0 else right
        return action

# %%
agent = BasicPolicyAgent(env)
state = env.reset()

total_reward = 0

for _ in range(100):
    action = agent.get_action(state)
    state, reward, done, info = env.step(action)
    # env.render()
    # time.sleep(0.03)
    if not done:
        total_reward += reward
env.close()
print("Reward: {}".format(total_reward))
# Out:
# Reward: 61.0

# %% [markdown]
# We can see that even with a very simple policy, the behavior is improved. Now we've seen how to interact with the environment and create agents.

# %% [markdown]
# Let's look at a simple implementation of the HillClimbing method.
# Essentially, we want a function that takes all the inputs (observations) available and outputs a vector with the predicted values of the next state of the environment based on a given action.
#
# Essentially we want to transform our input state vector [1 4] to a [1 2] output action vector. We do this by multiplying the [1 4] matrix with a  [4 2] weights matrix.
#
# This weights matrix is initialized with random weights. We use this initial weights matrix to get our action (output) vector from our observation (input) vector. We calculate the total reward from the episode, and save it as our best reward. We also save the weights matrix as our best weights. We then sample a new random weights matrix, to which we add a random noise matrix of the same dimensions for variance. If the new total reward is higher than the best total reward, we use the weights that gave us this new higher reward and save them as best weights, and halve the noise matrix to decrease variance. If the new total reward is lower, we keep the old weights and double the noise matrix:

# %%
class HillClimbingAgent():
    def __init__(self, env):
        self.state_dim = env.observation_space.shape
        # shape or dimension of the env's observation_shape matrix
        self.action_size = env.action_space.n
        self.build_model()
        
    def build_model(self):
            self.weights = 1e-4*np.random.rand(*self.state_dim, self.action_size)
            # initialize random weights matrix
            self.best_reward = -np.Inf
            # initialize reward as lowest possible number
            self.best_weights = np.copy(self.weights)
            # initialize best_weights as first random weights matrix
            self.noise_scale = 1e-2
            # initialize noise scale
            
        
    def get_action(self, state):
            p = np.dot(state, self.weights)
            # dot product of state and weights
            action = np.argmax(p)
            # action is highest element in p
            return action
        
    def update_model(self, reward):
            if reward >= self.best_reward:
                self.best_reward = reward
                self.best_weights = np.copy(self.weights)
                self.noise_scale = max(self.noise_scale/2, 1e-3)
            else:
                self.noise_scale = min(self.noise_scale*2, 2)
                    
            self.weights = self.best_weights + self.noise_scale * np.random.rand(*self.state_dim, self.action_size)
            # sample new current weights by adding best weight and noise matrix scaled by new noise scale

# %%
env_name = 'CartPole-v0'
env = gym.make(env_name)
num_runs = 1
run_rewards = []

for n in range(num_runs):
  print("Run {}".format(n))
  ep_rewards = []
  agent = HillClimbingAgent(env)
  num_episodes = 200

  for ep in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False
    while not done:
      action = agent.get_action(state)
      state, reward, done, info = env.step(action)
      # env.render()
      total_reward += reward
      # time.sleep(0.03)

    ep_rewards.append(total_reward)
    agent.update_model(total_reward)
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
run_rewards.append(ep_rewards)
env.close()

for n, ep_rewards in enumerate(run_rewards):
  x = range(len(ep_rewards))
  cumsum = np.cumsum(ep_rewards)
  avgs = [cumsum[ep]/(ep+1) if ep<100 else (cumsum[ep]-cumsum[ep-100])/100 for ep in x]
  plt.plot(x, avgs)
plt.title("HillClimbingAgent Performance")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
# Out:
# Run 0
# Episode: 0, total_reward: 10.00
# Episode: 1, total_reward: 10.00
# Episode: 2, total_reward: 10.00
# Episode: 3, total_reward: 10.00
# Episode: 4, total_reward: 9.00
# Episode: 5, total_reward: 10.00
# Episode: 6, total_reward: 10.00
# Episode: 7, total_reward: 10.00
# Episode: 8, total_reward: 9.00
# Episode: 9, total_reward: 10.00
# Episode: 10, total_reward: 10.00
# Episode: 11, total_reward: 9.00
# Episode: 12, total_reward: 9.00
# Episode: 13, total_reward: 10.00
# Episode: 14, total_reward: 8.00
# Episode: 15, total_reward: 39.00
# Episode: 16, total_reward: 32.00
# Episode: 17, total_reward: 97.00
# Episode: 18, total_reward: 70.00
# Episode: 19, total_reward: 29.00
# Episode: 20, total_reward: 49.00
# Episode: 21, total_reward: 66.00
# Episode: 22, total_reward: 10.00
# Episode: 23, total_reward: 118.00
# Episode: 24, total_reward: 9.00
# Episode: 25, total_reward: 69.00
# Episode: 26, total_reward: 96.00
# Episode: 27, total_reward: 200.00
# Episode: 28, total_reward: 117.00
# Episode: 29, total_reward: 36.00
# Episode: 30, total_reward: 162.00
# Episode: 31, total_reward: 46.00
# Episode: 32, total_reward: 80.00
# Episode: 33, total_reward: 10.00
# Episode: 34, total_reward: 18.00
# Episode: 35, total_reward: 144.00
# Episode: 36, total_reward: 9.00
# Episode: 37, total_reward: 10.00
# Episode: 38, total_reward: 10.00
# Episode: 39, total_reward: 10.00
# Episode: 40, total_reward: 28.00
# Episode: 41, total_reward: 10.00
# Episode: 42, total_reward: 33.00
# Episode: 43, total_reward: 10.00
# Episode: 44, total_reward: 10.00
# Episode: 45, total_reward: 10.00
# Episode: 46, total_reward: 9.00
# Episode: 47, total_reward: 21.00
# Episode: 48, total_reward: 200.00
# Episode: 49, total_reward: 49.00
# Episode: 50, total_reward: 200.00
# Episode: 51, total_reward: 200.00
# Episode: 52, total_reward: 200.00
# Episode: 53, total_reward: 68.00
# Episode: 54, total_reward: 200.00
# Episode: 55, total_reward: 200.00
# Episode: 56, total_reward: 200.00
# Episode: 57, total_reward: 48.00
# Episode: 58, total_reward: 52.00
# Episode: 59, total_reward: 66.00
# Episode: 60, total_reward: 113.00
# Episode: 61, total_reward: 68.00
# Episode: 62, total_reward: 200.00
# Episode: 63, total_reward: 86.00
# Episode: 64, total_reward: 200.00
# Episode: 65, total_reward: 58.00
# Episode: 66, total_reward: 200.00
# Episode: 67, total_reward: 93.00
# Episode: 68, total_reward: 115.00
# Episode: 69, total_reward: 84.00
# Episode: 70, total_reward: 200.00
# Episode: 71, total_reward: 200.00
# Episode: 72, total_reward: 200.00
# Episode: 73, total_reward: 200.00
# Episode: 74, total_reward: 109.00
# Episode: 75, total_reward: 56.00
# Episode: 76, total_reward: 200.00
# Episode: 77, total_reward: 58.00
# Episode: 78, total_reward: 200.00
# Episode: 79, total_reward: 200.00
# Episode: 80, total_reward: 200.00
# Episode: 81, total_reward: 200.00
# Episode: 82, total_reward: 200.00
# Episode: 83, total_reward: 67.00
# Episode: 84, total_reward: 82.00
# Episode: 85, total_reward: 78.00
# Episode: 86, total_reward: 58.00
# Episode: 87, total_reward: 63.00
# Episode: 88, total_reward: 87.00
# Episode: 89, total_reward: 62.00
# Episode: 90, total_reward: 200.00
# Episode: 91, total_reward: 52.00
# Episode: 92, total_reward: 100.00
# Episode: 93, total_reward: 53.00
# Episode: 94, total_reward: 83.00
# Episode: 95, total_reward: 54.00
# Episode: 96, total_reward: 200.00
# Episode: 97, total_reward: 200.00
# Episode: 98, total_reward: 200.00
# Episode: 99, total_reward: 200.00
# Episode: 100, total_reward: 200.00
# Episode: 101, total_reward: 200.00
# Episode: 102, total_reward: 200.00
# Episode: 103, total_reward: 200.00
# Episode: 104, total_reward: 200.00
# Episode: 105, total_reward: 76.00
# Episode: 106, total_reward: 200.00
# Episode: 107, total_reward: 114.00
# Episode: 108, total_reward: 200.00
# Episode: 109, total_reward: 200.00
# Episode: 110, total_reward: 82.00
# Episode: 111, total_reward: 200.00
# Episode: 112, total_reward: 200.00
# Episode: 113, total_reward: 200.00
# Episode: 114, total_reward: 200.00
# Episode: 115, total_reward: 86.00
# Episode: 116, total_reward: 200.00
# Episode: 117, total_reward: 78.00
# Episode: 118, total_reward: 200.00
# Episode: 119, total_reward: 200.00
# Episode: 120, total_reward: 200.00
# Episode: 121, total_reward: 200.00
# Episode: 122, total_reward: 200.00
# Episode: 123, total_reward: 200.00
# Episode: 124, total_reward: 200.00
# Episode: 125, total_reward: 200.00
# Episode: 126, total_reward: 75.00
# Episode: 127, total_reward: 73.00
# Episode: 128, total_reward: 200.00
# Episode: 129, total_reward: 200.00
# Episode: 130, total_reward: 200.00
# Episode: 131, total_reward: 200.00
# Episode: 132, total_reward: 200.00
# Episode: 133, total_reward: 200.00
# Episode: 134, total_reward: 200.00
# Episode: 135, total_reward: 200.00
# Episode: 136, total_reward: 200.00
# Episode: 137, total_reward: 84.00
# Episode: 138, total_reward: 200.00
# Episode: 139, total_reward: 200.00
# Episode: 140, total_reward: 200.00
# Episode: 141, total_reward: 200.00
# Episode: 142, total_reward: 75.00
# Episode: 143, total_reward: 111.00
# Episode: 144, total_reward: 200.00
# Episode: 145, total_reward: 200.00
# Episode: 146, total_reward: 78.00
# Episode: 147, total_reward: 200.00
# Episode: 148, total_reward: 200.00
# Episode: 149, total_reward: 140.00
# Episode: 150, total_reward: 200.00
# Episode: 151, total_reward: 200.00
# Episode: 152, total_reward: 200.00
# Episode: 153, total_reward: 200.00
# Episode: 154, total_reward: 200.00
# Episode: 155, total_reward: 200.00
# Episode: 156, total_reward: 82.00
# Episode: 157, total_reward: 200.00
# Episode: 158, total_reward: 200.00
# Episode: 159, total_reward: 200.00
# Episode: 160, total_reward: 200.00
# Episode: 161, total_reward: 85.00
# Episode: 162, total_reward: 62.00
# Episode: 163, total_reward: 72.00
# Episode: 164, total_reward: 200.00
# Episode: 165, total_reward: 200.00
# Episode: 166, total_reward: 200.00
# Episode: 167, total_reward: 200.00
# Episode: 168, total_reward: 200.00
# Episode: 169, total_reward: 200.00
# Episode: 170, total_reward: 200.00
# Episode: 171, total_reward: 200.00
# Episode: 172, total_reward: 200.00
# Episode: 173, total_reward: 200.00
# Episode: 174, total_reward: 200.00
# Episode: 175, total_reward: 90.00
# Episode: 176, total_reward: 200.00
# Episode: 177, total_reward: 200.00
# Episode: 178, total_reward: 74.00
# Episode: 179, total_reward: 72.00
# Episode: 180, total_reward: 78.00
# Episode: 181, total_reward: 200.00
# Episode: 182, total_reward: 200.00
# Episode: 183, total_reward: 200.00
# Episode: 184, total_reward: 200.00
# Episode: 185, total_reward: 200.00
# Episode: 186, total_reward: 200.00
# Episode: 187, total_reward: 200.00
# Episode: 188, total_reward: 200.00
# Episode: 189, total_reward: 200.00
# Episode: 190, total_reward: 80.00
# Episode: 191, total_reward: 200.00
# Episode: 192, total_reward: 200.00
# Episode: 193, total_reward: 90.00
# Episode: 194, total_reward: 115.00
# Episode: 195, total_reward: 106.00
# Episode: 196, total_reward: 100.00
# Episode: 197, total_reward: 92.00
# Episode: 198, total_reward: 200.00
# Episode: 199, total_reward: 200.00
# Text(0, 0.5, 'Average Reward')

# %% [markdown]
# After just 200 episodes, we can see that the agent is now able to keep the pole upright for the maximum 200 frames consistently (depending on how lucky you are with the random initialized weights matrix, this may take more episodes).

# %% [markdown]
# Let's try this method in a different gym environment. The acrobot system includes two joints and two links, where the joint between the two links is actuated. Initially, the links are hanging downwards, and the goal is to swing the end of the lower link up to a given height. The action is either applying +1, 0 or -1 torque on the joint between the two pendulum links. The Observation space or state consists of the sin() and cos() of the two rotational joint angles and the joint angular velocities.

# %%
env_name = "Acrobot-v1"
env = gym.make(env_name)
num_runs = 1
run_rewards = []

for n in range(num_runs):
  print("Run {}".format(n))
  ep_rewards = []
  agent = HillClimbingAgent(env)
  num_episodes = 500

  for ep in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False
    while not done:
      action = agent.get_action(state)
      state, reward, done, info = env.step(action)
      # env.render()
      total_reward += reward
      # time.sleep(0.03)

    ep_rewards.append(total_reward)
    agent.update_model(total_reward)
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
run_rewards.append(ep_rewards)
env.close()

for n, ep_rewards in enumerate(run_rewards):
  x = range(len(ep_rewards))
  cumsum = np.cumsum(ep_rewards)
  avgs = [cumsum[ep]/(ep+1) if ep<100 else (cumsum[ep]-cumsum[ep-100])/100 for ep in x]
  plt.plot(x, avgs)
plt.title("Agent Performance")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
# Out:
# Run 0
# Episode: 0, total_reward: -500.00
# Episode: 1, total_reward: -500.00
# Episode: 2, total_reward: -500.00
# Episode: 3, total_reward: -500.00
# Episode: 4, total_reward: -500.00
# Episode: 5, total_reward: -500.00
# Episode: 6, total_reward: -500.00
# Episode: 7, total_reward: -500.00
# Episode: 8, total_reward: -500.00
# Episode: 9, total_reward: -500.00
# Episode: 10, total_reward: -500.00
# Episode: 11, total_reward: -500.00
# Episode: 12, total_reward: -500.00
# Episode: 13, total_reward: -500.00
# Episode: 14, total_reward: -500.00
# Episode: 15, total_reward: -500.00
# Episode: 16, total_reward: -500.00
# Episode: 17, total_reward: -500.00
# Episode: 18, total_reward: -500.00
# Episode: 19, total_reward: -500.00
# Episode: 20, total_reward: -500.00
# Episode: 21, total_reward: -500.00
# Episode: 22, total_reward: -500.00
# Episode: 23, total_reward: -361.00
# Episode: 24, total_reward: -320.00
# Episode: 25, total_reward: -500.00
# Episode: 26, total_reward: -500.00
# Episode: 27, total_reward: -500.00
# Episode: 28, total_reward: -500.00
# Episode: 29, total_reward: -500.00
# Episode: 30, total_reward: -120.00
# Episode: 31, total_reward: -88.00
# Episode: 32, total_reward: -500.00
# Episode: 33, total_reward: -83.00
# Episode: 34, total_reward: -81.00
# Episode: 35, total_reward: -86.00
# Episode: 36, total_reward: -91.00
# Episode: 37, total_reward: -95.00
# Episode: 38, total_reward: -65.00
# Episode: 39, total_reward: -94.00
# Episode: 40, total_reward: -85.00
# Episode: 41, total_reward: -103.00
# Episode: 42, total_reward: -500.00
# Episode: 43, total_reward: -500.00
# Episode: 44, total_reward: -500.00
# Episode: 45, total_reward: -500.00
# Episode: 46, total_reward: -500.00
# Episode: 47, total_reward: -500.00
# Episode: 48, total_reward: -275.00
# Episode: 49, total_reward: -353.00
# Episode: 50, total_reward: -500.00
# Episode: 51, total_reward: -500.00
# Episode: 52, total_reward: -500.00
# Episode: 53, total_reward: -500.00
# Episode: 54, total_reward: -500.00
# Episode: 55, total_reward: -500.00
# Episode: 56, total_reward: -500.00
# Episode: 57, total_reward: -500.00
# Episode: 58, total_reward: -500.00
# Episode: 59, total_reward: -500.00
# Episode: 60, total_reward: -500.00
# Episode: 61, total_reward: -500.00
# Episode: 62, total_reward: -500.00
# Episode: 63, total_reward: -500.00
# Episode: 64, total_reward: -500.00
# Episode: 65, total_reward: -500.00
# Episode: 66, total_reward: -500.00
# Episode: 67, total_reward: -132.00
# Episode: 68, total_reward: -500.00
# Episode: 69, total_reward: -139.00
# Episode: 70, total_reward: -500.00
# Episode: 71, total_reward: -500.00
# Episode: 72, total_reward: -500.00
# Episode: 73, total_reward: -500.00
# Episode: 74, total_reward: -500.00
# Episode: 75, total_reward: -86.00
# Episode: 76, total_reward: -500.00
# Episode: 77, total_reward: -500.00
# Episode: 78, total_reward: -87.00
# Episode: 79, total_reward: -500.00
# Episode: 80, total_reward: -500.00
# Episode: 81, total_reward: -65.00
# Episode: 82, total_reward: -73.00
# Episode: 83, total_reward: -500.00
# Episode: 84, total_reward: -135.00
# Episode: 85, total_reward: -79.00
# Episode: 86, total_reward: -136.00
# Episode: 87, total_reward: -87.00
# Episode: 88, total_reward: -92.00
# Episode: 89, total_reward: -113.00
# Episode: 90, total_reward: -500.00
# Episode: 91, total_reward: -123.00
# Episode: 92, total_reward: -317.00
# Episode: 93, total_reward: -110.00
# Episode: 94, total_reward: -160.00
# Episode: 95, total_reward: -102.00
# Episode: 96, total_reward: -141.00
# Episode: 97, total_reward: -500.00
# Episode: 98, total_reward: -118.00
# Episode: 99, total_reward: -100.00
# Episode: 100, total_reward: -162.00
# Episode: 101, total_reward: -87.00
# Episode: 102, total_reward: -115.00
# Episode: 103, total_reward: -72.00
# Episode: 104, total_reward: -83.00
# Episode: 105, total_reward: -139.00
# Episode: 106, total_reward: -140.00
# Episode: 107, total_reward: -82.00
# Episode: 108, total_reward: -500.00
# Episode: 109, total_reward: -500.00
# Episode: 110, total_reward: -64.00
# Episode: 111, total_reward: -92.00
# Episode: 112, total_reward: -145.00
# Episode: 113, total_reward: -87.00
# Episode: 114, total_reward: -82.00
# Episode: 115, total_reward: -105.00
# Episode: 116, total_reward: -117.00
# Episode: 117, total_reward: -104.00
# Episode: 118, total_reward: -500.00
# Episode: 119, total_reward: -500.00
# Episode: 120, total_reward: -92.00
# Episode: 121, total_reward: -96.00
# Episode: 122, total_reward: -262.00
# Episode: 123, total_reward: -113.00
# Episode: 124, total_reward: -89.00
# Episode: 125, total_reward: -224.00
# Episode: 126, total_reward: -94.00
# Episode: 127, total_reward: -94.00
# Episode: 128, total_reward: -64.00
# Episode: 129, total_reward: -69.00
# Episode: 130, total_reward: -500.00
# Episode: 131, total_reward: -86.00
# Episode: 132, total_reward: -82.00
# Episode: 133, total_reward: -111.00
# Episode: 134, total_reward: -114.00
# Episode: 135, total_reward: -121.00
# Episode: 136, total_reward: -500.00
# Episode: 137, total_reward: -118.00
# Episode: 138, total_reward: -94.00
# Episode: 139, total_reward: -78.00
# Episode: 140, total_reward: -90.00
# Episode: 141, total_reward: -76.00
# Episode: 142, total_reward: -500.00
# Episode: 143, total_reward: -78.00
# Episode: 144, total_reward: -88.00
# Episode: 145, total_reward: -124.00
# Episode: 146, total_reward: -120.00
# Episode: 147, total_reward: -500.00
# Episode: 148, total_reward: -93.00
# Episode: 149, total_reward: -500.00
# Episode: 150, total_reward: -97.00
# Episode: 151, total_reward: -500.00
# Episode: 152, total_reward: -500.00
# Episode: 153, total_reward: -76.00
# Episode: 154, total_reward: -150.00
# Episode: 155, total_reward: -113.00
# Episode: 156, total_reward: -66.00
# Episode: 157, total_reward: -71.00
# Episode: 158, total_reward: -143.00
# Episode: 159, total_reward: -500.00
# Episode: 160, total_reward: -65.00
# Episode: 161, total_reward: -75.00
# Episode: 162, total_reward: -235.00
# Episode: 163, total_reward: -174.00
# Episode: 164, total_reward: -137.00
# Episode: 165, total_reward: -94.00
# Episode: 166, total_reward: -185.00
# Episode: 167, total_reward: -100.00
# Episode: 168, total_reward: -76.00
# Episode: 169, total_reward: -83.00
# Episode: 170, total_reward: -80.00
# Episode: 171, total_reward: -77.00
# Episode: 172, total_reward: -83.00
# Episode: 173, total_reward: -84.00
# Episode: 174, total_reward: -64.00
# Episode: 175, total_reward: -64.00
# Episode: 176, total_reward: -92.00
# Episode: 177, total_reward: -93.00
# Episode: 178, total_reward: -500.00
# Episode: 179, total_reward: -500.00
# Episode: 180, total_reward: -89.00
# Episode: 181, total_reward: -500.00
# Episode: 182, total_reward: -96.00
# Episode: 183, total_reward: -92.00
# Episode: 184, total_reward: -500.00
# Episode: 185, total_reward: -199.00
# Episode: 186, total_reward: -82.00
# Episode: 187, total_reward: -107.00
# Episode: 188, total_reward: -108.00
# Episode: 189, total_reward: -123.00
# Episode: 190, total_reward: -500.00
# Episode: 191, total_reward: -500.00
# Episode: 192, total_reward: -500.00
# Episode: 193, total_reward: -500.00
# Episode: 194, total_reward: -500.00
# Episode: 195, total_reward: -125.00
# Episode: 196, total_reward: -94.00
# Episode: 197, total_reward: -106.00
# Episode: 198, total_reward: -500.00
# Episode: 199, total_reward: -93.00
# Episode: 200, total_reward: -110.00
# Episode: 201, total_reward: -92.00
# Episode: 202, total_reward: -83.00
# Episode: 203, total_reward: -500.00
# Episode: 204, total_reward: -78.00
# Episode: 205, total_reward: -500.00
# Episode: 206, total_reward: -500.00
# Episode: 207, total_reward: -86.00
# Episode: 208, total_reward: -101.00
# Episode: 209, total_reward: -500.00
# Episode: 210, total_reward: -168.00
# Episode: 211, total_reward: -113.00
# Episode: 212, total_reward: -110.00
# Episode: 213, total_reward: -500.00
# Episode: 214, total_reward: -500.00
# Episode: 215, total_reward: -500.00
# Episode: 216, total_reward: -85.00
# Episode: 217, total_reward: -86.00
# Episode: 218, total_reward: -116.00
# Episode: 219, total_reward: -500.00
# Episode: 220, total_reward: -98.00
# Episode: 221, total_reward: -500.00
# Episode: 222, total_reward: -206.00
# Episode: 223, total_reward: -500.00
# Episode: 224, total_reward: -91.00
# Episode: 225, total_reward: -95.00
# Episode: 226, total_reward: -500.00
# Episode: 227, total_reward: -500.00
# Episode: 228, total_reward: -500.00
# Episode: 229, total_reward: -64.00
# Episode: 230, total_reward: -88.00
# Episode: 231, total_reward: -81.00
# Episode: 232, total_reward: -100.00
# Episode: 233, total_reward: -108.00
# Episode: 234, total_reward: -500.00
# Episode: 235, total_reward: -500.00
# Episode: 236, total_reward: -500.00
# Episode: 237, total_reward: -99.00
# Episode: 238, total_reward: -79.00
# Episode: 239, total_reward: -500.00
# Episode: 240, total_reward: -73.00
# Episode: 241, total_reward: -500.00
# Episode: 242, total_reward: -86.00
# Episode: 243, total_reward: -500.00
# Episode: 244, total_reward: -78.00
# Episode: 245, total_reward: -64.00
# Episode: 246, total_reward: -91.00
# Episode: 247, total_reward: -84.00
# Episode: 248, total_reward: -99.00
# Episode: 249, total_reward: -89.00
# Episode: 250, total_reward: -104.00
# Episode: 251, total_reward: -110.00
# Episode: 252, total_reward: -85.00
# Episode: 253, total_reward: -220.00
# Episode: 254, total_reward: -102.00
# Episode: 255, total_reward: -135.00
# Episode: 256, total_reward: -149.00
# Episode: 257, total_reward: -77.00
# Episode: 258, total_reward: -77.00
# Episode: 259, total_reward: -500.00
# Episode: 260, total_reward: -89.00
# Episode: 261, total_reward: -96.00
# Episode: 262, total_reward: -92.00
# Episode: 263, total_reward: -94.00
# Episode: 264, total_reward: -99.00
# Episode: 265, total_reward: -500.00
# Episode: 266, total_reward: -158.00
# Episode: 267, total_reward: -500.00
# Episode: 268, total_reward: -76.00
# Episode: 269, total_reward: -500.00
# Episode: 270, total_reward: -96.00
# Episode: 271, total_reward: -93.00
# Episode: 272, total_reward: -90.00
# Episode: 273, total_reward: -88.00
# Episode: 274, total_reward: -325.00
# Episode: 275, total_reward: -500.00
# Episode: 276, total_reward: -91.00
# Episode: 277, total_reward: -74.00
# Episode: 278, total_reward: -97.00
# Episode: 279, total_reward: -174.00
# Episode: 280, total_reward: -86.00
# Episode: 281, total_reward: -125.00
# Episode: 282, total_reward: -80.00
# Episode: 283, total_reward: -113.00
# Episode: 284, total_reward: -107.00
# Episode: 285, total_reward: -75.00
# Episode: 286, total_reward: -118.00
# Episode: 287, total_reward: -100.00
# Episode: 288, total_reward: -94.00
# Episode: 289, total_reward: -76.00
# Episode: 290, total_reward: -105.00
# Episode: 291, total_reward: -82.00
# Episode: 292, total_reward: -500.00
# Episode: 293, total_reward: -99.00
# Episode: 294, total_reward: -75.00
# Episode: 295, total_reward: -80.00
# Episode: 296, total_reward: -72.00
# Episode: 297, total_reward: -108.00
# Episode: 298, total_reward: -136.00
# Episode: 299, total_reward: -111.00
# Episode: 300, total_reward: -107.00
# Episode: 301, total_reward: -92.00
# Episode: 302, total_reward: -92.00
# Episode: 303, total_reward: -89.00
# Episode: 304, total_reward: -75.00
# Episode: 305, total_reward: -105.00
# Episode: 306, total_reward: -94.00
# Episode: 307, total_reward: -114.00
# Episode: 308, total_reward: -500.00
# Episode: 309, total_reward: -87.00
# Episode: 310, total_reward: -500.00
# Episode: 311, total_reward: -133.00
# Episode: 312, total_reward: -63.00
# Episode: 313, total_reward: -129.00
# Episode: 314, total_reward: -93.00
# Episode: 315, total_reward: -500.00
# Episode: 316, total_reward: -108.00
# Episode: 317, total_reward: -100.00
# Episode: 318, total_reward: -95.00
# Episode: 319, total_reward: -86.00
# Episode: 320, total_reward: -93.00
# Episode: 321, total_reward: -83.00
# Episode: 322, total_reward: -71.00
# Episode: 323, total_reward: -84.00
# Episode: 324, total_reward: -94.00
# Episode: 325, total_reward: -87.00
# Episode: 326, total_reward: -93.00
# Episode: 327, total_reward: -96.00
# Episode: 328, total_reward: -92.00
# Episode: 329, total_reward: -84.00
# Episode: 330, total_reward: -89.00
# Episode: 331, total_reward: -500.00
# Episode: 332, total_reward: -109.00
# Episode: 333, total_reward: -113.00
# Episode: 334, total_reward: -500.00
# Episode: 335, total_reward: -75.00
# Episode: 336, total_reward: -137.00
# Episode: 337, total_reward: -155.00
# Episode: 338, total_reward: -87.00
# Episode: 339, total_reward: -130.00
# Episode: 340, total_reward: -128.00
# Episode: 341, total_reward: -77.00
# Episode: 342, total_reward: -85.00
# Episode: 343, total_reward: -64.00
# Episode: 344, total_reward: -500.00
# Episode: 345, total_reward: -95.00
# Episode: 346, total_reward: -73.00
# Episode: 347, total_reward: -102.00
# Episode: 348, total_reward: -86.00
# Episode: 349, total_reward: -85.00
# Episode: 350, total_reward: -96.00
# Episode: 351, total_reward: -96.00
# Episode: 352, total_reward: -84.00
# Episode: 353, total_reward: -172.00
# Episode: 354, total_reward: -150.00
# Episode: 355, total_reward: -109.00
# Episode: 356, total_reward: -121.00
# Episode: 357, total_reward: -107.00
# Episode: 358, total_reward: -189.00
# Episode: 359, total_reward: -96.00
# Episode: 360, total_reward: -94.00
# Episode: 361, total_reward: -84.00
# Episode: 362, total_reward: -137.00
# Episode: 363, total_reward: -500.00
# Episode: 364, total_reward: -500.00
# Episode: 365, total_reward: -79.00
# Episode: 366, total_reward: -500.00
# Episode: 367, total_reward: -500.00
# Episode: 368, total_reward: -500.00
# Episode: 369, total_reward: -82.00
# Episode: 370, total_reward: -78.00
# Episode: 371, total_reward: -72.00
# Episode: 372, total_reward: -88.00
# Episode: 373, total_reward: -80.00
# Episode: 374, total_reward: -87.00
# Episode: 375, total_reward: -83.00
# Episode: 376, total_reward: -111.00
# Episode: 377, total_reward: -181.00
# Episode: 378, total_reward: -89.00
# Episode: 379, total_reward: -83.00
# Episode: 380, total_reward: -208.00
# Episode: 381, total_reward: -194.00
# Episode: 382, total_reward: -97.00
# Episode: 383, total_reward: -92.00
# Episode: 384, total_reward: -84.00
# Episode: 385, total_reward: -74.00
# Episode: 386, total_reward: -92.00
# Episode: 387, total_reward: -80.00
# Episode: 388, total_reward: -101.00
# Episode: 389, total_reward: -73.00
# Episode: 390, total_reward: -98.00
# Episode: 391, total_reward: -171.00
# Episode: 392, total_reward: -84.00
# Episode: 393, total_reward: -98.00
# Episode: 394, total_reward: -110.00
# Episode: 395, total_reward: -96.00
# Episode: 396, total_reward: -118.00
# Episode: 397, total_reward: -88.00
# Episode: 398, total_reward: -136.00
# Episode: 399, total_reward: -133.00
# Episode: 400, total_reward: -86.00
# Episode: 401, total_reward: -92.00
# Episode: 402, total_reward: -76.00
# Episode: 403, total_reward: -86.00
# Episode: 404, total_reward: -82.00
# Episode: 405, total_reward: -95.00
# Episode: 406, total_reward: -85.00
# Episode: 407, total_reward: -500.00
# Episode: 408, total_reward: -84.00
# Episode: 409, total_reward: -97.00
# Episode: 410, total_reward: -77.00
# Episode: 411, total_reward: -82.00
# Episode: 412, total_reward: -84.00
# Episode: 413, total_reward: -500.00
# Episode: 414, total_reward: -116.00
# Episode: 415, total_reward: -71.00
# Episode: 416, total_reward: -500.00
# Episode: 417, total_reward: -124.00
# Episode: 418, total_reward: -176.00
# Episode: 419, total_reward: -141.00
# Episode: 420, total_reward: -136.00
# Episode: 421, total_reward: -500.00
# Episode: 422, total_reward: -500.00
# Episode: 423, total_reward: -91.00
# Episode: 424, total_reward: -101.00
# Episode: 425, total_reward: -102.00
# Episode: 426, total_reward: -105.00
# Episode: 427, total_reward: -82.00
# Episode: 428, total_reward: -109.00
# Episode: 429, total_reward: -90.00
# Episode: 430, total_reward: -89.00
# Episode: 431, total_reward: -133.00
# Episode: 432, total_reward: -120.00
# Episode: 433, total_reward: -84.00
# Episode: 434, total_reward: -139.00
# Episode: 435, total_reward: -500.00
# Episode: 436, total_reward: -104.00
# Episode: 437, total_reward: -124.00
# Episode: 438, total_reward: -84.00
# Episode: 439, total_reward: -89.00
# Episode: 440, total_reward: -500.00
# Episode: 441, total_reward: -89.00
# Episode: 442, total_reward: -93.00
# Episode: 443, total_reward: -135.00
# Episode: 444, total_reward: -113.00
# Episode: 445, total_reward: -127.00
# Episode: 446, total_reward: -81.00
# Episode: 447, total_reward: -89.00
# Episode: 448, total_reward: -500.00
# Episode: 449, total_reward: -129.00
# Episode: 450, total_reward: -98.00
# Episode: 451, total_reward: -97.00
# Episode: 452, total_reward: -95.00
# Episode: 453, total_reward: -119.00
# Episode: 454, total_reward: -103.00
# Episode: 455, total_reward: -85.00
# Episode: 456, total_reward: -84.00
# Episode: 457, total_reward: -138.00
# Episode: 458, total_reward: -83.00
# Episode: 459, total_reward: -86.00
# Episode: 460, total_reward: -146.00
# Episode: 461, total_reward: -145.00
# Episode: 462, total_reward: -113.00
# Episode: 463, total_reward: -111.00
# Episode: 464, total_reward: -500.00
# Episode: 465, total_reward: -85.00
# Episode: 466, total_reward: -77.00
# Episode: 467, total_reward: -174.00
# Episode: 468, total_reward: -94.00
# Episode: 469, total_reward: -154.00
# Episode: 470, total_reward: -71.00
# Episode: 471, total_reward: -90.00
# Episode: 472, total_reward: -95.00
# Episode: 473, total_reward: -87.00
# Episode: 474, total_reward: -79.00
# Episode: 475, total_reward: -76.00
# Episode: 476, total_reward: -115.00
# Episode: 477, total_reward: -500.00
# Episode: 478, total_reward: -500.00
# Episode: 479, total_reward: -80.00
# Episode: 480, total_reward: -500.00
# Episode: 481, total_reward: -106.00
# Episode: 482, total_reward: -126.00
# Episode: 483, total_reward: -80.00
# Episode: 484, total_reward: -207.00
# Episode: 485, total_reward: -80.00
# Episode: 486, total_reward: -94.00
# Episode: 487, total_reward: -179.00
# Episode: 488, total_reward: -500.00
# Episode: 489, total_reward: -97.00
# Episode: 490, total_reward: -94.00
# Episode: 491, total_reward: -78.00
# Episode: 492, total_reward: -75.00
# Episode: 493, total_reward: -460.00
# Episode: 494, total_reward: -500.00
# Episode: 495, total_reward: -500.00
# Episode: 496, total_reward: -66.00
# Episode: 497, total_reward: -83.00
# Episode: 498, total_reward: -100.00
# Episode: 499, total_reward: -97.00
# Text(0, 0.5, 'Average Reward')

# %% [markdown]
# We can see here that the HillClimbing method does not work as well in this environment as it did for the CartPole environment. Looking at the CartPole environment, this method sometimes lead to a high reward, and in a subsequent run a lower reward. Note that sampling the weights matrix never saves the individual best weights for each matrix, essentially each action-state -> reward combination isn't individually saved but rather the entire weights matrix. We'll revisit this later.

# %% [markdown]
# Now let's try our HillClimbingAgent in the MountainCar-v0 environment. The goal is to get the car to the top of the mountain. A reward of -1 is given each timestep, and a reward of 0 is given when the goal is reached.
#
# Observation space: state[0] = car xpos; state[1] = car velocity |
# Action space: action[0] = push left; action[1] = no push; action[2] = push right

# %%
env_name = "MountainCar-v0"
env = gym.make(env_name)
num_runs = 1
run_rewards = []

for n in range(num_runs):
  print("Run {}".format(n))
  ep_rewards = []
  agent = HillClimbingAgent(env)
  num_episodes = 200

  for ep in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False
    while not done:
      action = agent.get_action(state)
      state, reward, done, info = env.step(action)
      # env.render()
      total_reward += reward
      # time.sleep(0.03)

    ep_rewards.append(total_reward)
    agent.update_model(total_reward)
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
run_rewards.append(ep_rewards)
env.close()

for n, ep_rewards in enumerate(run_rewards):
  x = range(len(ep_rewards))
  cumsum = np.cumsum(ep_rewards)
  avgs = [cumsum[ep]/(ep+1) if ep<100 else (cumsum[ep]-cumsum[ep-100])/100 for ep in x]
  plt.plot(x, avgs)
plt.title("Agent Performance")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
# Out:
# Run 0
# Episode: 0, total_reward: -200.00
# Episode: 1, total_reward: -200.00
# Episode: 2, total_reward: -200.00
# Episode: 3, total_reward: -200.00
# Episode: 4, total_reward: -200.00
# Episode: 5, total_reward: -200.00
# Episode: 6, total_reward: -200.00
# Episode: 7, total_reward: -200.00
# Episode: 8, total_reward: -200.00
# Episode: 9, total_reward: -200.00
# Episode: 10, total_reward: -200.00
# Episode: 11, total_reward: -200.00
# Episode: 12, total_reward: -200.00
# Episode: 13, total_reward: -200.00
# Episode: 14, total_reward: -200.00
# Episode: 15, total_reward: -200.00
# Episode: 16, total_reward: -200.00
# Episode: 17, total_reward: -200.00
# Episode: 18, total_reward: -200.00
# Episode: 19, total_reward: -200.00
# Episode: 20, total_reward: -200.00
# Episode: 21, total_reward: -200.00
# Episode: 22, total_reward: -200.00
# Episode: 23, total_reward: -200.00
# Episode: 24, total_reward: -200.00
# Episode: 25, total_reward: -200.00
# Episode: 26, total_reward: -200.00
# Episode: 27, total_reward: -200.00
# Episode: 28, total_reward: -200.00
# Episode: 29, total_reward: -200.00
# Episode: 30, total_reward: -200.00
# Episode: 31, total_reward: -200.00
# Episode: 32, total_reward: -200.00
# Episode: 33, total_reward: -200.00
# Episode: 34, total_reward: -200.00
# Episode: 35, total_reward: -200.00
# Episode: 36, total_reward: -200.00
# Episode: 37, total_reward: -200.00
# Episode: 38, total_reward: -200.00
# Episode: 39, total_reward: -200.00
# Episode: 40, total_reward: -200.00
# Episode: 41, total_reward: -200.00
# Episode: 42, total_reward: -200.00
# Episode: 43, total_reward: -200.00
# Episode: 44, total_reward: -200.00
# Episode: 45, total_reward: -200.00
# Episode: 46, total_reward: -200.00
# Episode: 47, total_reward: -200.00
# Episode: 48, total_reward: -200.00
# Episode: 49, total_reward: -200.00
# Episode: 50, total_reward: -200.00
# Episode: 51, total_reward: -200.00
# Episode: 52, total_reward: -200.00
# Episode: 53, total_reward: -200.00
# Episode: 54, total_reward: -200.00
# Episode: 55, total_reward: -200.00
# Episode: 56, total_reward: -200.00
# Episode: 57, total_reward: -200.00
# Episode: 58, total_reward: -200.00
# Episode: 59, total_reward: -200.00
# Episode: 60, total_reward: -200.00
# Episode: 61, total_reward: -200.00
# Episode: 62, total_reward: -200.00
# Episode: 63, total_reward: -200.00
# Episode: 64, total_reward: -200.00
# Episode: 65, total_reward: -200.00
# Episode: 66, total_reward: -200.00
# Episode: 67, total_reward: -200.00
# Episode: 68, total_reward: -200.00
# Episode: 69, total_reward: -200.00
# Episode: 70, total_reward: -200.00
# Episode: 71, total_reward: -200.00
# Episode: 72, total_reward: -200.00
# Episode: 73, total_reward: -200.00
# Episode: 74, total_reward: -200.00
# Episode: 75, total_reward: -200.00
# Episode: 76, total_reward: -200.00
# Episode: 77, total_reward: -200.00
# Episode: 78, total_reward: -200.00
# Episode: 79, total_reward: -200.00
# Episode: 80, total_reward: -200.00
# Episode: 81, total_reward: -200.00
# Episode: 82, total_reward: -200.00
# Episode: 83, total_reward: -200.00
# Episode: 84, total_reward: -200.00
# Episode: 85, total_reward: -200.00
# Episode: 86, total_reward: -200.00
# Episode: 87, total_reward: -200.00
# Episode: 88, total_reward: -200.00
# Episode: 89, total_reward: -200.00
# Episode: 90, total_reward: -200.00
# Episode: 91, total_reward: -200.00
# Episode: 92, total_reward: -200.00
# Episode: 93, total_reward: -200.00
# Episode: 94, total_reward: -200.00
# Episode: 95, total_reward: -200.00
# Episode: 96, total_reward: -200.00
# Episode: 97, total_reward: -200.00
# Episode: 98, total_reward: -200.00
# Episode: 99, total_reward: -200.00
# Episode: 100, total_reward: -200.00
# Episode: 101, total_reward: -200.00
# Episode: 102, total_reward: -200.00
# Episode: 103, total_reward: -200.00
# Episode: 104, total_reward: -200.00
# Episode: 105, total_reward: -200.00
# Episode: 106, total_reward: -200.00
# Episode: 107, total_reward: -200.00
# Episode: 108, total_reward: -200.00
# Episode: 109, total_reward: -200.00
# Episode: 110, total_reward: -200.00
# Episode: 111, total_reward: -200.00
# Episode: 112, total_reward: -200.00
# Episode: 113, total_reward: -200.00
# Episode: 114, total_reward: -200.00
# Episode: 115, total_reward: -200.00
# Episode: 116, total_reward: -200.00
# Episode: 117, total_reward: -200.00
# Episode: 118, total_reward: -200.00
# Episode: 119, total_reward: -200.00
# Episode: 120, total_reward: -200.00
# Episode: 121, total_reward: -200.00
# Episode: 122, total_reward: -200.00
# Episode: 123, total_reward: -200.00
# Episode: 124, total_reward: -200.00
# Episode: 125, total_reward: -200.00
# Episode: 126, total_reward: -200.00
# Episode: 127, total_reward: -200.00
# Episode: 128, total_reward: -200.00
# Episode: 129, total_reward: -200.00
# Episode: 130, total_reward: -200.00
# Episode: 131, total_reward: -200.00
# Episode: 132, total_reward: -200.00
# Episode: 133, total_reward: -200.00
# Episode: 134, total_reward: -200.00
# Episode: 135, total_reward: -200.00
# Episode: 136, total_reward: -200.00
# Episode: 137, total_reward: -200.00
# Episode: 138, total_reward: -200.00
# Episode: 139, total_reward: -200.00
# Episode: 140, total_reward: -200.00
# Episode: 141, total_reward: -200.00
# Episode: 142, total_reward: -200.00
# Episode: 143, total_reward: -200.00
# Episode: 144, total_reward: -200.00
# Episode: 145, total_reward: -200.00
# Episode: 146, total_reward: -200.00
# Episode: 147, total_reward: -200.00
# Episode: 148, total_reward: -200.00
# Episode: 149, total_reward: -200.00
# Episode: 150, total_reward: -200.00
# Episode: 151, total_reward: -200.00
# Episode: 152, total_reward: -200.00
# Episode: 153, total_reward: -200.00
# Episode: 154, total_reward: -200.00
# Episode: 155, total_reward: -200.00
# Episode: 156, total_reward: -200.00
# Episode: 157, total_reward: -200.00
# Episode: 158, total_reward: -200.00
# Episode: 159, total_reward: -200.00
# Episode: 160, total_reward: -200.00
# Episode: 161, total_reward: -200.00
# Episode: 162, total_reward: -200.00
# Episode: 163, total_reward: -200.00
# Episode: 164, total_reward: -200.00
# Episode: 165, total_reward: -200.00
# Episode: 166, total_reward: -200.00
# Episode: 167, total_reward: -200.00
# Episode: 168, total_reward: -200.00
# Episode: 169, total_reward: -200.00
# Episode: 170, total_reward: -200.00
# Episode: 171, total_reward: -200.00
# Episode: 172, total_reward: -200.00
# Episode: 173, total_reward: -200.00
# Episode: 174, total_reward: -200.00
# Episode: 175, total_reward: -200.00
# Episode: 176, total_reward: -200.00
# Episode: 177, total_reward: -200.00
# Episode: 178, total_reward: -200.00
# Episode: 179, total_reward: -200.00
# Episode: 180, total_reward: -200.00
# Episode: 181, total_reward: -200.00
# Episode: 182, total_reward: -200.00
# Episode: 183, total_reward: -200.00
# Episode: 184, total_reward: -200.00
# Episode: 185, total_reward: -200.00
# Episode: 186, total_reward: -200.00
# Episode: 187, total_reward: -200.00
# Episode: 188, total_reward: -200.00
# Episode: 189, total_reward: -200.00
# Episode: 190, total_reward: -200.00
# Episode: 191, total_reward: -200.00
# Episode: 192, total_reward: -200.00
# Episode: 193, total_reward: -200.00
# Episode: 194, total_reward: -200.00
# Episode: 195, total_reward: -200.00
# Episode: 196, total_reward: -200.00
# Episode: 197, total_reward: -200.00
# Episode: 198, total_reward: -200.00
# Episode: 199, total_reward: -200.00
# Text(0, 0.5, 'Average Reward')

# %% [markdown]
# One of the reasons the MountainCar-v0 env is harder than the CartPole env is that the goal state is not easily reached randomly, as the car motor does not have enough power by itself to get to the goal, whereas with the CartPole the goal state is the initial state. Due to the nature of the reward in this env, this means the HillClimbing agent rarely if ever reaches a better reward, as it is exploring actions randomly and there is no incremental reward. Over time the increasing variance of the added noise may lead to to improved rewards but it can take a long time.

# %% [markdown]
# Now let's introduce Q-Learning; it is a reinforcement learning algorithm that aims to find the best action to take given a current state to maximize reward. This algorithm is considered off-policy due to the fact the Q-learning function learns from actions outside the current policy, like taking random actions.
#
# The first step is to create a Q-table (or matrix) that follows the shape of [state, action] and we initialize each value in the matrix to zero. We update and store our Q-values in this matrix after each episode. This then becomes a reference table for our agent to select the best action based on the highest Q-value.
#
# The second step is to interact with the environment, and update the state-action pairs in our Q-table. This is done in one of two ways: exploiting, or exploring. When exploiting, the Q-table is used as reference to view all possible actions for a given state, and the agent selects the action based on the max value of said action. When exploring, the action is taken randomly. This is important as it allows the agent to explore and discover new states that may not be selected during exploitation. These two modes of interaction with the environment are balanced using a variable usually named epsilon, which determines the probability of exploring versus exploiting.
#
# We've mentioned epsilon (exploration probability), one of the hyperparameters, there are others that are useful. The learning rate, sometimes denoted alpha, is how much an updated value is "accepted" vs the old one. The difference between the new and old value is multiplied by this learning rate and added to the previous q-value. A discount factor, usually denoted gamma, can be used to balance immediate and future reward.

# %%
class QAgent():
    def __init__(self, env, buckets=(3, 3, 6, 6,), min_alpha=0.1, min_epsilon=0.1, gamma=1.0, ada_divisor=20):
        self.env = env # for choosing different environments
        self.buckets = buckets # down-scaling feature space to discrete range
        self.min_alpha = min_alpha # learning rate
        self.min_epsilon = min_epsilon # exploration rate
        self.gamma = gamma # discount factor
        self.ada_divisor = ada_divisor # decay rate parameter for alpha and epsilon

        # initialising Q-table
        self.Q = np.zeros(self.buckets + (self.env.action_space.n,))

    # Discretizing input space to make Q-table and to reduce dimmensionality
    def discretize(self, state):
        upper_bounds = [self.env.observation_space.high[0], 0.5, self.env.observation_space.high[2], math.radians(50)]
        lower_bounds = [self.env.observation_space.low[0], -0.5, self.env.observation_space.low[2], -math.radians(50)]
        ratios = [(state[i] + abs(lower_bounds[i])) / (upper_bounds[i] - lower_bounds[i]) for i in range(len(state))]
        discretized_state = [int(round((self.buckets[i] - 1) * ratios[i])) for i in range(len(state))]
        discretized_state = [min(self.buckets[i] - 1, max(0, discretized_state[i])) for i in range(len(state))]
        return tuple(discretized_state)

    # Choosing action based on epsilon-greedy policy
    def choose_action(self, state, epsilon):
        return self.env.action_space.sample() if (np.random.random() <= epsilon) else np.argmax(self.Q[state])

    # Updating Q-value of state-action pair based on the Bellman equation
    def update_q(self, state, action, reward, next_state, alpha):
        self.Q[state][action] += alpha * (reward + self.gamma * np.max(self.Q[next_state]) - self.Q[state][action])

    # Reduce Exploration Rate Over time
    def get_epsilon(self, t):
        return max(self.min_epsilon, min(1, 1.0 - math.log10((t + 1) / self.ada_divisor)))

    # Reduce Learning Rate over time
    def get_alpha(self, t):
        return max(self.min_alpha, min(1.0, 1.0 - math.log10((t + 1) / self.ada_divisor)))

# %%
num_runs = 1
run_rewards = []
env = gym.make('CartPole-v0')

for n in range(num_runs):
  print("Run {}".format(n))
  ep_rewards = []
  num_episodes = 1000
  agent = QAgent(env)

  for ep in range(num_episodes):
    # As states are continuous, discretize them into buckets
    discretized_state = agent.discretize(env.reset())

    # Get adaptive learning alpha and epsilon decayed over time
    alpha = agent.get_alpha(ep)
    epsilon = agent.get_epsilon(ep)
            
    total_reward = 0
    done = False
    i = 0
    
    while not done:
        # Choose action according to greedy policy and take it
        action = agent.choose_action(discretized_state, epsilon)
        state, reward, done, info = env.step(action)
        next_state = agent.discretize(state)
        # Update Q-Table
        agent.update_q(discretized_state, action, reward, next_state, alpha)
        discretized_state = next_state
        i += 1
        # env.render()
        total_reward += reward
        # time.sleep(0.03)
    ep_rewards.append(total_reward)
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
run_rewards.append(ep_rewards)
env.close()

for n, ep_rewards in enumerate(run_rewards):
  x = range(len(ep_rewards))
  cumsum = np.cumsum(ep_rewards)
  avgs = [cumsum[ep]/(ep+1) if ep<100 else (cumsum[ep]-cumsum[ep-100])/100 for ep in x]
  plt.plot(x, avgs)
plt.title("Agent Performance")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
# Out:
# Run 0
# Episode: 0, total_reward: 30.00
# Episode: 1, total_reward: 20.00
# Episode: 2, total_reward: 27.00
# Episode: 3, total_reward: 16.00
# Episode: 4, total_reward: 53.00
# Episode: 5, total_reward: 18.00
# Episode: 6, total_reward: 33.00
# Episode: 7, total_reward: 25.00
# Episode: 8, total_reward: 18.00
# Episode: 9, total_reward: 15.00
# Episode: 10, total_reward: 22.00
# Episode: 11, total_reward: 17.00
# Episode: 12, total_reward: 44.00
# Episode: 13, total_reward: 42.00
# Episode: 14, total_reward: 20.00
# Episode: 15, total_reward: 19.00
# Episode: 16, total_reward: 19.00
# Episode: 17, total_reward: 32.00
# Episode: 18, total_reward: 11.00
# Episode: 19, total_reward: 31.00
# Episode: 20, total_reward: 26.00
# Episode: 21, total_reward: 27.00
# Episode: 22, total_reward: 27.00
# Episode: 23, total_reward: 17.00
# Episode: 24, total_reward: 25.00
# Episode: 25, total_reward: 14.00
# Episode: 26, total_reward: 12.00
# Episode: 27, total_reward: 40.00
# Episode: 28, total_reward: 29.00
# Episode: 29, total_reward: 20.00
# Episode: 30, total_reward: 18.00
# Episode: 31, total_reward: 28.00
# Episode: 32, total_reward: 14.00
# Episode: 33, total_reward: 21.00
# Episode: 34, total_reward: 27.00
# Episode: 35, total_reward: 47.00
# Episode: 36, total_reward: 19.00
# Episode: 37, total_reward: 17.00
# Episode: 38, total_reward: 20.00
# Episode: 39, total_reward: 10.00
# Episode: 40, total_reward: 36.00
# Episode: 41, total_reward: 39.00
# Episode: 42, total_reward: 31.00
# Episode: 43, total_reward: 15.00
# Episode: 44, total_reward: 52.00
# Episode: 45, total_reward: 23.00
# Episode: 46, total_reward: 38.00
# Episode: 47, total_reward: 24.00
# Episode: 48, total_reward: 25.00
# Episode: 49, total_reward: 15.00
# Episode: 50, total_reward: 15.00
# Episode: 51, total_reward: 19.00
# Episode: 52, total_reward: 135.00
# Episode: 53, total_reward: 31.00
# Episode: 54, total_reward: 28.00
# Episode: 55, total_reward: 28.00
# Episode: 56, total_reward: 61.00
# Episode: 57, total_reward: 46.00
# Episode: 58, total_reward: 64.00
# Episode: 59, total_reward: 50.00
# Episode: 60, total_reward: 45.00
# Episode: 61, total_reward: 29.00
# Episode: 62, total_reward: 13.00
# Episode: 63, total_reward: 12.00
# Episode: 64, total_reward: 49.00
# Episode: 65, total_reward: 39.00
# Episode: 66, total_reward: 11.00
# Episode: 67, total_reward: 22.00
# Episode: 68, total_reward: 59.00
# Episode: 69, total_reward: 14.00
# Episode: 70, total_reward: 27.00
# Episode: 71, total_reward: 73.00
# Episode: 72, total_reward: 29.00
# Episode: 73, total_reward: 199.00
# Episode: 74, total_reward: 27.00
# Episode: 75, total_reward: 61.00
# Episode: 76, total_reward: 18.00
# Episode: 77, total_reward: 16.00
# Episode: 78, total_reward: 25.00
# Episode: 79, total_reward: 125.00
# Episode: 80, total_reward: 12.00
# Episode: 81, total_reward: 28.00
# Episode: 82, total_reward: 31.00
# Episode: 83, total_reward: 26.00
# Episode: 84, total_reward: 55.00
# Episode: 85, total_reward: 92.00
# Episode: 86, total_reward: 122.00
# Episode: 87, total_reward: 126.00
# Episode: 88, total_reward: 46.00
# Episode: 89, total_reward: 107.00
# Episode: 90, total_reward: 29.00
# Episode: 91, total_reward: 34.00
# Episode: 92, total_reward: 32.00
# Episode: 93, total_reward: 48.00
# Episode: 94, total_reward: 56.00
# Episode: 95, total_reward: 71.00
# Episode: 96, total_reward: 64.00
# Episode: 97, total_reward: 136.00
# Episode: 98, total_reward: 24.00
# Episode: 99, total_reward: 200.00
# Episode: 100, total_reward: 68.00
# Episode: 101, total_reward: 43.00
# Episode: 102, total_reward: 26.00
# Episode: 103, total_reward: 17.00
# Episode: 104, total_reward: 88.00
# Episode: 105, total_reward: 59.00
# Episode: 106, total_reward: 105.00
# Episode: 107, total_reward: 179.00
# Episode: 108, total_reward: 80.00
# Episode: 109, total_reward: 50.00
# Episode: 110, total_reward: 86.00
# Episode: 111, total_reward: 77.00
# Episode: 112, total_reward: 96.00
# Episode: 113, total_reward: 64.00
# Episode: 114, total_reward: 200.00
# Episode: 115, total_reward: 49.00
# Episode: 116, total_reward: 192.00
# Episode: 117, total_reward: 104.00
# Episode: 118, total_reward: 200.00
# Episode: 119, total_reward: 200.00
# Episode: 120, total_reward: 26.00
# Episode: 121, total_reward: 48.00
# Episode: 122, total_reward: 100.00
# Episode: 123, total_reward: 76.00
# Episode: 124, total_reward: 117.00
# Episode: 125, total_reward: 68.00
# Episode: 126, total_reward: 124.00
# Episode: 127, total_reward: 200.00
# Episode: 128, total_reward: 200.00
# Episode: 129, total_reward: 81.00
# Episode: 130, total_reward: 125.00
# Episode: 131, total_reward: 85.00
# Episode: 132, total_reward: 93.00
# Episode: 133, total_reward: 80.00
# Episode: 134, total_reward: 103.00
# Episode: 135, total_reward: 94.00
# Episode: 136, total_reward: 95.00
# Episode: 137, total_reward: 192.00
# Episode: 138, total_reward: 57.00
# Episode: 139, total_reward: 120.00
# Episode: 140, total_reward: 149.00
# Episode: 141, total_reward: 104.00
# Episode: 142, total_reward: 105.00
# Episode: 143, total_reward: 173.00
# Episode: 144, total_reward: 64.00
# Episode: 145, total_reward: 81.00
# Episode: 146, total_reward: 25.00
# Episode: 147, total_reward: 106.00
# Episode: 148, total_reward: 52.00
# Episode: 149, total_reward: 200.00
# Episode: 150, total_reward: 160.00
# Episode: 151, total_reward: 151.00
# Episode: 152, total_reward: 135.00
# Episode: 153, total_reward: 186.00
# Episode: 154, total_reward: 122.00
# Episode: 155, total_reward: 87.00
# Episode: 156, total_reward: 83.00
# Episode: 157, total_reward: 116.00
# Episode: 158, total_reward: 63.00
# Episode: 159, total_reward: 114.00
# Episode: 160, total_reward: 121.00
# Episode: 161, total_reward: 82.00
# Episode: 162, total_reward: 137.00
# Episode: 163, total_reward: 124.00
# Episode: 164, total_reward: 200.00
# Episode: 165, total_reward: 93.00
# Episode: 166, total_reward: 135.00
# Episode: 167, total_reward: 200.00
# Episode: 168, total_reward: 200.00
# Episode: 169, total_reward: 200.00
# Episode: 170, total_reward: 200.00
# Episode: 171, total_reward: 188.00
# Episode: 172, total_reward: 200.00
# Episode: 173, total_reward: 200.00
# Episode: 174, total_reward: 177.00
# Episode: 175, total_reward: 180.00
# Episode: 176, total_reward: 71.00
# Episode: 177, total_reward: 89.00
# Episode: 178, total_reward: 200.00
# Episode: 179, total_reward: 200.00
# Episode: 180, total_reward: 200.00
# Episode: 181, total_reward: 200.00
# Episode: 182, total_reward: 200.00
# Episode: 183, total_reward: 200.00
# Episode: 184, total_reward: 190.00
# Episode: 185, total_reward: 200.00
# Episode: 186, total_reward: 25.00
# Episode: 187, total_reward: 78.00
# Episode: 188, total_reward: 200.00
# Episode: 189, total_reward: 180.00
# Episode: 190, total_reward: 23.00
# Episode: 191, total_reward: 25.00
# Episode: 192, total_reward: 200.00
# Episode: 193, total_reward: 57.00
# Episode: 194, total_reward: 125.00
# Episode: 195, total_reward: 109.00
# Episode: 196, total_reward: 200.00
# Episode: 197, total_reward: 125.00
# Episode: 198, total_reward: 151.00
# Episode: 199, total_reward: 193.00
# Episode: 200, total_reward: 200.00
# Episode: 201, total_reward: 147.00
# Episode: 202, total_reward: 125.00
# Episode: 203, total_reward: 100.00
# Episode: 204, total_reward: 146.00
# Episode: 205, total_reward: 162.00
# Episode: 206, total_reward: 200.00
# Episode: 207, total_reward: 194.00
# Episode: 208, total_reward: 29.00
# Episode: 209, total_reward: 61.00
# Episode: 210, total_reward: 165.00
# Episode: 211, total_reward: 36.00
# Episode: 212, total_reward: 200.00
# Episode: 213, total_reward: 144.00
# Episode: 214, total_reward: 25.00
# Episode: 215, total_reward: 200.00
# Episode: 216, total_reward: 27.00
# Episode: 217, total_reward: 28.00
# Episode: 218, total_reward: 200.00
# Episode: 219, total_reward: 200.00
# Episode: 220, total_reward: 50.00
# Episode: 221, total_reward: 200.00
# Episode: 222, total_reward: 200.00
# Episode: 223, total_reward: 142.00
# Episode: 224, total_reward: 200.00
# Episode: 225, total_reward: 200.00
# Episode: 226, total_reward: 200.00
# Episode: 227, total_reward: 200.00
# Episode: 228, total_reward: 200.00
# Episode: 229, total_reward: 172.00
# Episode: 230, total_reward: 200.00
# Episode: 231, total_reward: 200.00
# Episode: 232, total_reward: 200.00
# Episode: 233, total_reward: 200.00
# Episode: 234, total_reward: 200.00
# Episode: 235, total_reward: 200.00
# Episode: 236, total_reward: 200.00
# Episode: 237, total_reward: 200.00
# Episode: 238, total_reward: 200.00
# Episode: 239, total_reward: 200.00
# Episode: 240, total_reward: 200.00
# Episode: 241, total_reward: 200.00
# Episode: 242, total_reward: 200.00
# Episode: 243, total_reward: 200.00
# Episode: 244, total_reward: 192.00
# Episode: 245, total_reward: 200.00
# Episode: 246, total_reward: 200.00
# Episode: 247, total_reward: 200.00
# Episode: 248, total_reward: 200.00
# Episode: 249, total_reward: 200.00
# Episode: 250, total_reward: 200.00
# Episode: 251, total_reward: 200.00
# Episode: 252, total_reward: 200.00
# Episode: 253, total_reward: 200.00
# Episode: 254, total_reward: 200.00
# Episode: 255, total_reward: 200.00
# Episode: 256, total_reward: 94.00
# Episode: 257, total_reward: 73.00
# Episode: 258, total_reward: 200.00
# Episode: 259, total_reward: 200.00
# Episode: 260, total_reward: 168.00
# Episode: 261, total_reward: 200.00
# Episode: 262, total_reward: 118.00
# Episode: 263, total_reward: 200.00
# Episode: 264, total_reward: 200.00
# Episode: 265, total_reward: 147.00
# Episode: 266, total_reward: 200.00
# Episode: 267, total_reward: 200.00
# Episode: 268, total_reward: 124.00
# Episode: 269, total_reward: 200.00
# Episode: 270, total_reward: 200.00
# Episode: 271, total_reward: 200.00
# Episode: 272, total_reward: 200.00
# Episode: 273, total_reward: 200.00
# Episode: 274, total_reward: 200.00
# Episode: 275, total_reward: 96.00
# Episode: 276, total_reward: 200.00
# Episode: 277, total_reward: 200.00
# Episode: 278, total_reward: 200.00
# Episode: 279, total_reward: 200.00
# Episode: 280, total_reward: 200.00
# Episode: 281, total_reward: 200.00
# Episode: 282, total_reward: 200.00
# Episode: 283, total_reward: 200.00
# Episode: 284, total_reward: 200.00
# Episode: 285, total_reward: 200.00
# Episode: 286, total_reward: 200.00
# Episode: 287, total_reward: 200.00
# Episode: 288, total_reward: 200.00
# Episode: 289, total_reward: 200.00
# Episode: 290, total_reward: 200.00
# Episode: 291, total_reward: 200.00
# Episode: 292, total_reward: 200.00
# Episode: 293, total_reward: 200.00
# Episode: 294, total_reward: 200.00
# Episode: 295, total_reward: 200.00
# Episode: 296, total_reward: 164.00
# Episode: 297, total_reward: 200.00
# Episode: 298, total_reward: 200.00
# Episode: 299, total_reward: 200.00
# Episode: 300, total_reward: 94.00
# Episode: 301, total_reward: 200.00
# Episode: 302, total_reward: 200.00
# Episode: 303, total_reward: 200.00
# Episode: 304, total_reward: 200.00
# Episode: 305, total_reward: 200.00
# Episode: 306, total_reward: 196.00
# Episode: 307, total_reward: 200.00
# Episode: 308, total_reward: 200.00
# Episode: 309, total_reward: 200.00
# Episode: 310, total_reward: 200.00
# Episode: 311, total_reward: 200.00
# Episode: 312, total_reward: 200.00
# Episode: 313, total_reward: 200.00
# Episode: 314, total_reward: 71.00
# Episode: 315, total_reward: 21.00
# Episode: 316, total_reward: 72.00
# Episode: 317, total_reward: 103.00
# Episode: 318, total_reward: 118.00
# Episode: 319, total_reward: 200.00
# Episode: 320, total_reward: 200.00
# Episode: 321, total_reward: 200.00
# Episode: 322, total_reward: 200.00
# Episode: 323, total_reward: 97.00
# Episode: 324, total_reward: 200.00
# Episode: 325, total_reward: 70.00
# Episode: 326, total_reward: 200.00
# Episode: 327, total_reward: 140.00
# Episode: 328, total_reward: 122.00
# Episode: 329, total_reward: 110.00
# Episode: 330, total_reward: 152.00
# Episode: 331, total_reward: 148.00
# Episode: 332, total_reward: 157.00
# Episode: 333, total_reward: 132.00
# Episode: 334, total_reward: 157.00
# Episode: 335, total_reward: 79.00
# Episode: 336, total_reward: 200.00
# Episode: 337, total_reward: 200.00
# Episode: 338, total_reward: 107.00
# Episode: 339, total_reward: 200.00
# Episode: 340, total_reward: 200.00
# Episode: 341, total_reward: 165.00
# Episode: 342, total_reward: 170.00
# Episode: 343, total_reward: 200.00
# Episode: 344, total_reward: 105.00
# Episode: 345, total_reward: 76.00
# Episode: 346, total_reward: 64.00
# Episode: 347, total_reward: 26.00
# Episode: 348, total_reward: 200.00
# Episode: 349, total_reward: 110.00
# Episode: 350, total_reward: 62.00
# Episode: 351, total_reward: 35.00
# Episode: 352, total_reward: 110.00
# Episode: 353, total_reward: 143.00
# Episode: 354, total_reward: 78.00
# Episode: 355, total_reward: 45.00
# Episode: 356, total_reward: 22.00
# Episode: 357, total_reward: 71.00
# Episode: 358, total_reward: 17.00
# Episode: 359, total_reward: 34.00
# Episode: 360, total_reward: 60.00
# Episode: 361, total_reward: 75.00
# Episode: 362, total_reward: 16.00
# Episode: 363, total_reward: 13.00
# Episode: 364, total_reward: 144.00
# Episode: 365, total_reward: 103.00
# Episode: 366, total_reward: 200.00
# Episode: 367, total_reward: 177.00
# Episode: 368, total_reward: 128.00
# Episode: 369, total_reward: 114.00
# Episode: 370, total_reward: 171.00
# Episode: 371, total_reward: 152.00
# Episode: 372, total_reward: 193.00
# Episode: 373, total_reward: 200.00
# Episode: 374, total_reward: 173.00
# Episode: 375, total_reward: 200.00
# Episode: 376, total_reward: 121.00
# Episode: 377, total_reward: 66.00
# Episode: 378, total_reward: 128.00
# Episode: 379, total_reward: 200.00
# Episode: 380, total_reward: 199.00
# Episode: 381, total_reward: 110.00
# Episode: 382, total_reward: 200.00
# Episode: 383, total_reward: 119.00
# Episode: 384, total_reward: 133.00
# Episode: 385, total_reward: 188.00
# Episode: 386, total_reward: 158.00
# Episode: 387, total_reward: 124.00
# Episode: 388, total_reward: 164.00
# Episode: 389, total_reward: 67.00
# Episode: 390, total_reward: 170.00
# Episode: 391, total_reward: 200.00
# Episode: 392, total_reward: 165.00
# Episode: 393, total_reward: 153.00
# Episode: 394, total_reward: 129.00
# Episode: 395, total_reward: 131.00
# Episode: 396, total_reward: 112.00
# Episode: 397, total_reward: 200.00
# Episode: 398, total_reward: 92.00
# Episode: 399, total_reward: 150.00
# Episode: 400, total_reward: 85.00
# Episode: 401, total_reward: 200.00
# Episode: 402, total_reward: 200.00
# Episode: 403, total_reward: 109.00
# Episode: 404, total_reward: 200.00
# Episode: 405, total_reward: 200.00
# Episode: 406, total_reward: 64.00
# Episode: 407, total_reward: 164.00
# Episode: 408, total_reward: 105.00
# Episode: 409, total_reward: 142.00
# Episode: 410, total_reward: 183.00
# Episode: 411, total_reward: 200.00
# Episode: 412, total_reward: 161.00
# Episode: 413, total_reward: 35.00
# Episode: 414, total_reward: 200.00
# Episode: 415, total_reward: 133.00
# Episode: 416, total_reward: 25.00
# Episode: 417, total_reward: 102.00
# Episode: 418, total_reward: 29.00
# Episode: 419, total_reward: 152.00
# Episode: 420, total_reward: 129.00
# Episode: 421, total_reward: 28.00
# Episode: 422, total_reward: 27.00
# Episode: 423, total_reward: 200.00
# Episode: 424, total_reward: 13.00
# Episode: 425, total_reward: 29.00
# Episode: 426, total_reward: 171.00
# Episode: 427, total_reward: 200.00
# Episode: 428, total_reward: 200.00
# Episode: 429, total_reward: 149.00
# Episode: 430, total_reward: 200.00
# Episode: 431, total_reward: 73.00
# Episode: 432, total_reward: 200.00
# Episode: 433, total_reward: 200.00
# Episode: 434, total_reward: 200.00
# Episode: 435, total_reward: 106.00
# Episode: 436, total_reward: 200.00
# Episode: 437, total_reward: 200.00
# Episode: 438, total_reward: 200.00
# Episode: 439, total_reward: 200.00
# Episode: 440, total_reward: 200.00
# Episode: 441, total_reward: 165.00
# Episode: 442, total_reward: 33.00
# Episode: 443, total_reward: 200.00
# Episode: 444, total_reward: 200.00
# Episode: 445, total_reward: 21.00
# Episode: 446, total_reward: 200.00
# Episode: 447, total_reward: 200.00
# Episode: 448, total_reward: 200.00
# Episode: 449, total_reward: 200.00
# Episode: 450, total_reward: 200.00
# Episode: 451, total_reward: 200.00
# Episode: 452, total_reward: 200.00
# Episode: 453, total_reward: 200.00
# Episode: 454, total_reward: 200.00
# Episode: 455, total_reward: 200.00
# Episode: 456, total_reward: 200.00
# Episode: 457, total_reward: 200.00
# Episode: 458, total_reward: 200.00
# Episode: 459, total_reward: 200.00
# Episode: 460, total_reward: 200.00
# Episode: 461, total_reward: 200.00
# Episode: 462, total_reward: 200.00
# Episode: 463, total_reward: 200.00
# Episode: 464, total_reward: 200.00
# Episode: 465, total_reward: 200.00
# Episode: 466, total_reward: 200.00
# Episode: 467, total_reward: 200.00
# Episode: 468, total_reward: 200.00
# Episode: 469, total_reward: 129.00
# Episode: 470, total_reward: 200.00
# Episode: 471, total_reward: 91.00
# Episode: 472, total_reward: 200.00
# Episode: 473, total_reward: 113.00
# Episode: 474, total_reward: 200.00
# Episode: 475, total_reward: 200.00
# Episode: 476, total_reward: 200.00
# Episode: 477, total_reward: 200.00
# Episode: 478, total_reward: 200.00
# Episode: 479, total_reward: 200.00
# Episode: 480, total_reward: 200.00
# Episode: 481, total_reward: 113.00
# Episode: 482, total_reward: 75.00
# Episode: 483, total_reward: 182.00
# Episode: 484, total_reward: 200.00
# Episode: 485, total_reward: 200.00
# Episode: 486, total_reward: 200.00
# Episode: 487, total_reward: 154.00
# Episode: 488, total_reward: 98.00
# Episode: 489, total_reward: 166.00
# Episode: 490, total_reward: 200.00
# Episode: 491, total_reward: 200.00
# Episode: 492, total_reward: 184.00
# Episode: 493, total_reward: 200.00
# Episode: 494, total_reward: 200.00
# Episode: 495, total_reward: 200.00
# Episode: 496, total_reward: 105.00
# Episode: 497, total_reward: 101.00
# Episode: 498, total_reward: 125.00
# Episode: 499, total_reward: 200.00
# Episode: 500, total_reward: 200.00
# Episode: 501, total_reward: 200.00
# Episode: 502, total_reward: 200.00
# Episode: 503, total_reward: 200.00
# Episode: 504, total_reward: 200.00
# Episode: 505, total_reward: 200.00
# Episode: 506, total_reward: 200.00
# Episode: 507, total_reward: 200.00
# Episode: 508, total_reward: 200.00
# Episode: 509, total_reward: 200.00
# Episode: 510, total_reward: 85.00
# Episode: 511, total_reward: 200.00
# Episode: 512, total_reward: 200.00
# Episode: 513, total_reward: 104.00
# Episode: 514, total_reward: 167.00
# Episode: 515, total_reward: 200.00
# Episode: 516, total_reward: 200.00
# Episode: 517, total_reward: 52.00
# Episode: 518, total_reward: 200.00
# Episode: 519, total_reward: 200.00
# Episode: 520, total_reward: 200.00
# Episode: 521, total_reward: 200.00
# Episode: 522, total_reward: 135.00
# Episode: 523, total_reward: 200.00
# Episode: 524, total_reward: 200.00
# Episode: 525, total_reward: 200.00
# Episode: 526, total_reward: 200.00
# Episode: 527, total_reward: 200.00
# Episode: 528, total_reward: 200.00
# Episode: 529, total_reward: 200.00
# Episode: 530, total_reward: 200.00
# Episode: 531, total_reward: 200.00
# Episode: 532, total_reward: 200.00
# Episode: 533, total_reward: 200.00
# Episode: 534, total_reward: 200.00
# Episode: 535, total_reward: 200.00
# Episode: 536, total_reward: 200.00
# Episode: 537, total_reward: 200.00
# Episode: 538, total_reward: 200.00
# Episode: 539, total_reward: 200.00
# Episode: 540, total_reward: 200.00
# Episode: 541, total_reward: 149.00
# Episode: 542, total_reward: 200.00
# Episode: 543, total_reward: 200.00
# Episode: 544, total_reward: 200.00
# Episode: 545, total_reward: 200.00
# Episode: 546, total_reward: 135.00
# Episode: 547, total_reward: 200.00
# Episode: 548, total_reward: 68.00
# Episode: 549, total_reward: 200.00
# Episode: 550, total_reward: 200.00
# Episode: 551, total_reward: 200.00
# Episode: 552, total_reward: 200.00
# Episode: 553, total_reward: 200.00
# Episode: 554, total_reward: 21.00
# Episode: 555, total_reward: 28.00
# Episode: 556, total_reward: 118.00
# Episode: 557, total_reward: 66.00
# Episode: 558, total_reward: 154.00
# Episode: 559, total_reward: 157.00
# Episode: 560, total_reward: 110.00
# Episode: 561, total_reward: 120.00
# Episode: 562, total_reward: 117.00
# Episode: 563, total_reward: 179.00
# Episode: 564, total_reward: 12.00
# Episode: 565, total_reward: 87.00
# Episode: 566, total_reward: 175.00
# Episode: 567, total_reward: 200.00
# Episode: 568, total_reward: 122.00
# Episode: 569, total_reward: 150.00
# Episode: 570, total_reward: 123.00
# Episode: 571, total_reward: 200.00
# Episode: 572, total_reward: 188.00
# Episode: 573, total_reward: 200.00
# Episode: 574, total_reward: 200.00
# Episode: 575, total_reward: 200.00
# Episode: 576, total_reward: 165.00
# Episode: 577, total_reward: 200.00
# Episode: 578, total_reward: 200.00
# Episode: 579, total_reward: 136.00
# Episode: 580, total_reward: 161.00
# Episode: 581, total_reward: 200.00
# Episode: 582, total_reward: 105.00
# Episode: 583, total_reward: 161.00
# Episode: 584, total_reward: 170.00
# Episode: 585, total_reward: 200.00
# Episode: 586, total_reward: 200.00
# Episode: 587, total_reward: 200.00
# Episode: 588, total_reward: 122.00
# Episode: 589, total_reward: 145.00
# Episode: 590, total_reward: 150.00
# Episode: 591, total_reward: 200.00
# Episode: 592, total_reward: 200.00
# Episode: 593, total_reward: 200.00
# Episode: 594, total_reward: 200.00
# Episode: 595, total_reward: 200.00
# Episode: 596, total_reward: 200.00
# Episode: 597, total_reward: 200.00
# Episode: 598, total_reward: 21.00
# Episode: 599, total_reward: 200.00
# Episode: 600, total_reward: 200.00
# Episode: 601, total_reward: 200.00
# Episode: 602, total_reward: 200.00
# Episode: 603, total_reward: 200.00
# Episode: 604, total_reward: 109.00
# Episode: 605, total_reward: 200.00
# Episode: 606, total_reward: 200.00
# Episode: 607, total_reward: 100.00
# Episode: 608, total_reward: 200.00
# Episode: 609, total_reward: 200.00
# Episode: 610, total_reward: 200.00
# Episode: 611, total_reward: 200.00
# Episode: 612, total_reward: 200.00
# Episode: 613, total_reward: 121.00
# Episode: 614, total_reward: 200.00
# Episode: 615, total_reward: 200.00
# Episode: 616, total_reward: 200.00
# Episode: 617, total_reward: 200.00
# Episode: 618, total_reward: 200.00
# Episode: 619, total_reward: 200.00
# Episode: 620, total_reward: 174.00
# Episode: 621, total_reward: 200.00
# Episode: 622, total_reward: 200.00
# Episode: 623, total_reward: 200.00
# Episode: 624, total_reward: 200.00
# Episode: 625, total_reward: 200.00
# Episode: 626, total_reward: 149.00
# Episode: 627, total_reward: 200.00
# Episode: 628, total_reward: 26.00
# Episode: 629, total_reward: 65.00
# Episode: 630, total_reward: 70.00
# Episode: 631, total_reward: 92.00
# Episode: 632, total_reward: 121.00
# Episode: 633, total_reward: 200.00
# Episode: 634, total_reward: 101.00
# Episode: 635, total_reward: 200.00
# Episode: 636, total_reward: 159.00
# Episode: 637, total_reward: 27.00
# Episode: 638, total_reward: 200.00
# Episode: 639, total_reward: 63.00
# Episode: 640, total_reward: 200.00
# Episode: 641, total_reward: 121.00
# Episode: 642, total_reward: 94.00
# Episode: 643, total_reward: 200.00
# Episode: 644, total_reward: 200.00
# Episode: 645, total_reward: 200.00
# Episode: 646, total_reward: 200.00
# Episode: 647, total_reward: 200.00
# Episode: 648, total_reward: 200.00
# Episode: 649, total_reward: 200.00
# Episode: 650, total_reward: 200.00
# Episode: 651, total_reward: 200.00
# Episode: 652, total_reward: 200.00
# Episode: 653, total_reward: 200.00
# Episode: 654, total_reward: 200.00
# Episode: 655, total_reward: 200.00
# Episode: 656, total_reward: 200.00
# Episode: 657, total_reward: 200.00
# Episode: 658, total_reward: 200.00
# Episode: 659, total_reward: 200.00
# Episode: 660, total_reward: 200.00
# Episode: 661, total_reward: 200.00
# Episode: 662, total_reward: 200.00
# Episode: 663, total_reward: 200.00
# Episode: 664, total_reward: 200.00
# Episode: 665, total_reward: 200.00
# Episode: 666, total_reward: 200.00
# Episode: 667, total_reward: 200.00
# Episode: 668, total_reward: 200.00
# Episode: 669, total_reward: 200.00
# Episode: 670, total_reward: 200.00
# Episode: 671, total_reward: 200.00
# Episode: 672, total_reward: 200.00
# Episode: 673, total_reward: 200.00
# Episode: 674, total_reward: 200.00
# Episode: 675, total_reward: 200.00
# Episode: 676, total_reward: 200.00
# Episode: 677, total_reward: 200.00
# Episode: 678, total_reward: 200.00
# Episode: 679, total_reward: 161.00
# Episode: 680, total_reward: 200.00
# Episode: 681, total_reward: 77.00
# Episode: 682, total_reward: 200.00
# Episode: 683, total_reward: 90.00
# Episode: 684, total_reward: 200.00
# Episode: 685, total_reward: 200.00
# Episode: 686, total_reward: 200.00
# Episode: 687, total_reward: 200.00
# Episode: 688, total_reward: 200.00
# Episode: 689, total_reward: 200.00
# Episode: 690, total_reward: 197.00
# Episode: 691, total_reward: 200.00
# Episode: 692, total_reward: 200.00
# Episode: 693, total_reward: 200.00
# Episode: 694, total_reward: 200.00
# Episode: 695, total_reward: 200.00
# Episode: 696, total_reward: 200.00
# Episode: 697, total_reward: 200.00
# Episode: 698, total_reward: 200.00
# Episode: 699, total_reward: 200.00
# Episode: 700, total_reward: 200.00
# Episode: 701, total_reward: 200.00
# Episode: 702, total_reward: 200.00
# Episode: 703, total_reward: 200.00
# Episode: 704, total_reward: 200.00
# Episode: 705, total_reward: 200.00
# Episode: 706, total_reward: 200.00
# Episode: 707, total_reward: 200.00
# Episode: 708, total_reward: 200.00
# Episode: 709, total_reward: 200.00
# Episode: 710, total_reward: 200.00
# Episode: 711, total_reward: 200.00
# Episode: 712, total_reward: 200.00
# Episode: 713, total_reward: 200.00
# Episode: 714, total_reward: 200.00
# Episode: 715, total_reward: 200.00
# Episode: 716, total_reward: 200.00
# Episode: 717, total_reward: 200.00
# Episode: 718, total_reward: 200.00
# Episode: 719, total_reward: 200.00
# Episode: 720, total_reward: 200.00
# Episode: 721, total_reward: 111.00
# Episode: 722, total_reward: 200.00
# Episode: 723, total_reward: 150.00
# Episode: 724, total_reward: 25.00
# Episode: 725, total_reward: 21.00
# Episode: 726, total_reward: 58.00
# Episode: 727, total_reward: 200.00
# Episode: 728, total_reward: 200.00
# Episode: 729, total_reward: 200.00
# Episode: 730, total_reward: 200.00
# Episode: 731, total_reward: 200.00
# Episode: 732, total_reward: 73.00
# Episode: 733, total_reward: 200.00
# Episode: 734, total_reward: 21.00
# Episode: 735, total_reward: 61.00
# Episode: 736, total_reward: 200.00
# Episode: 737, total_reward: 200.00
# Episode: 738, total_reward: 200.00
# Episode: 739, total_reward: 200.00
# Episode: 740, total_reward: 19.00
# Episode: 741, total_reward: 26.00
# Episode: 742, total_reward: 200.00
# Episode: 743, total_reward: 200.00
# Episode: 744, total_reward: 200.00
# Episode: 745, total_reward: 200.00
# Episode: 746, total_reward: 200.00
# Episode: 747, total_reward: 200.00
# Episode: 748, total_reward: 200.00
# Episode: 749, total_reward: 200.00
# Episode: 750, total_reward: 200.00
# Episode: 751, total_reward: 200.00
# Episode: 752, total_reward: 200.00
# Episode: 753, total_reward: 200.00
# Episode: 754, total_reward: 200.00
# Episode: 755, total_reward: 200.00
# Episode: 756, total_reward: 200.00
# Episode: 757, total_reward: 200.00
# Episode: 758, total_reward: 200.00
# Episode: 759, total_reward: 200.00
# Episode: 760, total_reward: 200.00
# Episode: 761, total_reward: 200.00
# Episode: 762, total_reward: 200.00
# Episode: 763, total_reward: 200.00
# Episode: 764, total_reward: 200.00
# Episode: 765, total_reward: 200.00
# Episode: 766, total_reward: 200.00
# Episode: 767, total_reward: 200.00
# Episode: 768, total_reward: 200.00
# Episode: 769, total_reward: 200.00
# Episode: 770, total_reward: 200.00
# Episode: 771, total_reward: 200.00
# Episode: 772, total_reward: 200.00
# Episode: 773, total_reward: 200.00
# Episode: 774, total_reward: 200.00
# Episode: 775, total_reward: 200.00
# Episode: 776, total_reward: 200.00
# Episode: 777, total_reward: 200.00
# Episode: 778, total_reward: 61.00
# Episode: 779, total_reward: 200.00
# Episode: 780, total_reward: 200.00
# Episode: 781, total_reward: 200.00
# Episode: 782, total_reward: 200.00
# Episode: 783, total_reward: 200.00
# Episode: 784, total_reward: 200.00
# Episode: 785, total_reward: 200.00
# Episode: 786, total_reward: 200.00
# Episode: 787, total_reward: 200.00
# Episode: 788, total_reward: 200.00
# Episode: 789, total_reward: 200.00
# Episode: 790, total_reward: 200.00
# Episode: 791, total_reward: 200.00
# Episode: 792, total_reward: 200.00
# Episode: 793, total_reward: 200.00
# Episode: 794, total_reward: 200.00
# Episode: 795, total_reward: 200.00
# Episode: 796, total_reward: 200.00
# Episode: 797, total_reward: 200.00
# Episode: 798, total_reward: 200.00
# Episode: 799, total_reward: 200.00
# Episode: 800, total_reward: 200.00
# Episode: 801, total_reward: 200.00
# Episode: 802, total_reward: 200.00
# Episode: 803, total_reward: 151.00
# Episode: 804, total_reward: 24.00
# Episode: 805, total_reward: 24.00
# Episode: 806, total_reward: 76.00
# Episode: 807, total_reward: 69.00
# Episode: 808, total_reward: 76.00
# Episode: 809, total_reward: 200.00
# Episode: 810, total_reward: 200.00
# Episode: 811, total_reward: 200.00
# Episode: 812, total_reward: 200.00
# Episode: 813, total_reward: 200.00
# Episode: 814, total_reward: 200.00
# Episode: 815, total_reward: 200.00
# Episode: 816, total_reward: 200.00
# Episode: 817, total_reward: 200.00
# Episode: 818, total_reward: 200.00
# Episode: 819, total_reward: 200.00
# Episode: 820, total_reward: 200.00
# Episode: 821, total_reward: 200.00
# Episode: 822, total_reward: 200.00
# Episode: 823, total_reward: 200.00
# Episode: 824, total_reward: 200.00
# Episode: 825, total_reward: 200.00
# Episode: 826, total_reward: 200.00
# Episode: 827, total_reward: 20.00
# Episode: 828, total_reward: 200.00
# Episode: 829, total_reward: 200.00
# Episode: 830, total_reward: 200.00
# Episode: 831, total_reward: 200.00
# Episode: 832, total_reward: 200.00
# Episode: 833, total_reward: 200.00
# Episode: 834, total_reward: 200.00
# Episode: 835, total_reward: 200.00
# Episode: 836, total_reward: 200.00
# Episode: 837, total_reward: 200.00
# Episode: 838, total_reward: 200.00
# Episode: 839, total_reward: 200.00
# Episode: 840, total_reward: 200.00
# Episode: 841, total_reward: 200.00
# Episode: 842, total_reward: 200.00
# Episode: 843, total_reward: 200.00
# Episode: 844, total_reward: 200.00
# Episode: 845, total_reward: 200.00
# Episode: 846, total_reward: 200.00
# Episode: 847, total_reward: 200.00
# Episode: 848, total_reward: 200.00
# Episode: 849, total_reward: 200.00
# Episode: 850, total_reward: 200.00
# Episode: 851, total_reward: 200.00
# Episode: 852, total_reward: 200.00
# Episode: 853, total_reward: 200.00
# Episode: 854, total_reward: 200.00
# Episode: 855, total_reward: 200.00
# Episode: 856, total_reward: 200.00
# Episode: 857, total_reward: 200.00
# Episode: 858, total_reward: 200.00
# Episode: 859, total_reward: 200.00
# Episode: 860, total_reward: 200.00
# Episode: 861, total_reward: 200.00
# Episode: 862, total_reward: 200.00
# Episode: 863, total_reward: 200.00
# Episode: 864, total_reward: 200.00
# Episode: 865, total_reward: 200.00
# Episode: 866, total_reward: 200.00
# Episode: 867, total_reward: 200.00
# Episode: 868, total_reward: 200.00
# Episode: 869, total_reward: 200.00
# Episode: 870, total_reward: 200.00
# Episode: 871, total_reward: 146.00
# Episode: 872, total_reward: 200.00
# Episode: 873, total_reward: 200.00
# Episode: 874, total_reward: 200.00
# Episode: 875, total_reward: 200.00
# Episode: 876, total_reward: 200.00
# Episode: 877, total_reward: 200.00
# Episode: 878, total_reward: 200.00
# Episode: 879, total_reward: 200.00
# Episode: 880, total_reward: 200.00
# Episode: 881, total_reward: 200.00
# Episode: 882, total_reward: 200.00
# Episode: 883, total_reward: 200.00
# Episode: 884, total_reward: 200.00
# Episode: 885, total_reward: 200.00
# Episode: 886, total_reward: 200.00
# Episode: 887, total_reward: 200.00
# Episode: 888, total_reward: 200.00
# Episode: 889, total_reward: 200.00
# Episode: 890, total_reward: 200.00
# Episode: 891, total_reward: 200.00
# Episode: 892, total_reward: 200.00
# Episode: 893, total_reward: 200.00
# Episode: 894, total_reward: 193.00
# Episode: 895, total_reward: 200.00
# Episode: 896, total_reward: 200.00
# Episode: 897, total_reward: 200.00
# Episode: 898, total_reward: 200.00
# Episode: 899, total_reward: 200.00
# Episode: 900, total_reward: 200.00
# Episode: 901, total_reward: 200.00
# Episode: 902, total_reward: 200.00
# Episode: 903, total_reward: 200.00
# Episode: 904, total_reward: 200.00
# Episode: 905, total_reward: 200.00
# Episode: 906, total_reward: 200.00
# Episode: 907, total_reward: 200.00
# Episode: 908, total_reward: 200.00
# Episode: 909, total_reward: 200.00
# Episode: 910, total_reward: 200.00
# Episode: 911, total_reward: 200.00
# Episode: 912, total_reward: 200.00
# Episode: 913, total_reward: 200.00
# Episode: 914, total_reward: 200.00
# Episode: 915, total_reward: 200.00
# Episode: 916, total_reward: 200.00
# Episode: 917, total_reward: 200.00
# Episode: 918, total_reward: 200.00
# Episode: 919, total_reward: 200.00
# Episode: 920, total_reward: 200.00
# Episode: 921, total_reward: 200.00
# Episode: 922, total_reward: 200.00
# Episode: 923, total_reward: 200.00
# Episode: 924, total_reward: 200.00
# Episode: 925, total_reward: 200.00
# Episode: 926, total_reward: 200.00
# Episode: 927, total_reward: 200.00
# Episode: 928, total_reward: 200.00
# Episode: 929, total_reward: 200.00
# Episode: 930, total_reward: 200.00
# Episode: 931, total_reward: 200.00
# Episode: 932, total_reward: 200.00
# Episode: 933, total_reward: 200.00
# Episode: 934, total_reward: 200.00
# Episode: 935, total_reward: 200.00
# Episode: 936, total_reward: 200.00
# Episode: 937, total_reward: 200.00
# Episode: 938, total_reward: 200.00
# Episode: 939, total_reward: 200.00
# Episode: 940, total_reward: 200.00
# Episode: 941, total_reward: 200.00
# Episode: 942, total_reward: 200.00
# Episode: 943, total_reward: 25.00
# Episode: 944, total_reward: 200.00
# Episode: 945, total_reward: 200.00
# Episode: 946, total_reward: 200.00
# Episode: 947, total_reward: 200.00
# Episode: 948, total_reward: 200.00
# Episode: 949, total_reward: 200.00
# Episode: 950, total_reward: 200.00
# Episode: 951, total_reward: 200.00
# Episode: 952, total_reward: 200.00
# Episode: 953, total_reward: 200.00
# Episode: 954, total_reward: 200.00
# Episode: 955, total_reward: 200.00
# Episode: 956, total_reward: 200.00
# Episode: 957, total_reward: 200.00
# Episode: 958, total_reward: 200.00
# Episode: 959, total_reward: 200.00
# Episode: 960, total_reward: 200.00
# Episode: 961, total_reward: 200.00
# Episode: 962, total_reward: 200.00
# Episode: 963, total_reward: 200.00
# Episode: 964, total_reward: 200.00
# Episode: 965, total_reward: 200.00
# Episode: 966, total_reward: 200.00
# Episode: 967, total_reward: 200.00
# Episode: 968, total_reward: 200.00
# Episode: 969, total_reward: 23.00
# Episode: 970, total_reward: 181.00
# Episode: 971, total_reward: 200.00
# Episode: 972, total_reward: 200.00
# Episode: 973, total_reward: 200.00
# Episode: 974, total_reward: 200.00
# Episode: 975, total_reward: 200.00
# Episode: 976, total_reward: 200.00
# Episode: 977, total_reward: 200.00
# Episode: 978, total_reward: 200.00
# Episode: 979, total_reward: 200.00
# Episode: 980, total_reward: 200.00
# Episode: 981, total_reward: 200.00
# Episode: 982, total_reward: 200.00
# Episode: 983, total_reward: 200.00
# Episode: 984, total_reward: 200.00
# Episode: 985, total_reward: 200.00
# Episode: 986, total_reward: 200.00
# Episode: 987, total_reward: 200.00
# Episode: 988, total_reward: 200.00
# Episode: 989, total_reward: 200.00
# Episode: 990, total_reward: 200.00
# Episode: 991, total_reward: 200.00
# Episode: 992, total_reward: 200.00
# Episode: 993, total_reward: 200.00
# Episode: 994, total_reward: 200.00
# Episode: 995, total_reward: 200.00
# Episode: 996, total_reward: 200.00
# Episode: 997, total_reward: 200.00
# Episode: 998, total_reward: 200.00
# Episode: 999, total_reward: 200.00
# Text(0, 0.5, 'Average Reward')

# %%
import keras
from keras.models import  Sequential
from keras.layers import Dense
from keras.optimizers import Adam

max_score = 0

n_win_tick = 1000
max_env_steps = 1000

#environment Parameters
memory = deque(maxlen=100000)
if max_env_steps is not None:
    env._max_episode_steps = max_env_steps
    
model = keras.Sequential()
model.add(Dense(24,input_dim=4,activation='relu'))
model.add(Dense(48, activation='relu'))
model.add(Dense(96, activation='relu'))
model.add(Dense(48, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(2,activation='relu'))
model.compile(loss='mse', optimizer=Adam(lr=0.01, decay=0.01))
    

class DQNAgent():
    def __init__(self, env, model, gamma = 1.0, epsilon = 1.0, epsilon_min = 0.01, 
                 epsilon_decay = 0.999, alpha = 0.01, alpha_decay = 0.01, 
                 alpha_test_factor = 1.0, batch_size = 256):
        self.env = env
        self.model = model
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.alpha = alpha
        self.alpha_decay = alpha_decay
        self.alpha_test_fact0r = alpha_test_factor
        self.batch_size = batch_size
        
        

    
        
        
        #Define functions
    def remember(self, state, action, reward, next_state, done):
        memory.append((state, action, reward, next_state, done))
    def choose_action(self, state, epsilon):
        if np.random.random() <= epsilon:
            return env.action_space.sample()
        else:
            return np.argmax(model.predict(state))
    def get_epsilon(self, t):
        return max(self.epsilon_min, min(self.epsilon,1.0 - math.log10((t+1)*self.epsilon_decay)))
    def preprocess(self, state):
        return np.reshape(state, [1,4])
    def replay(self, batch_size,epsilon):
        x_batch, y_batch = [], []
        minibatch = random.sample(memory, min(len(memory), batch_size))
        for state, action, reward, next_state, done in minibatch:
            y_target = model.predict(state)
            y_target[0][action] = reward if done else reward + gamma * np.max(model.predict(next_state)[0])
            x_batch.append(state[0])
            y_batch.append(y_target[0])
        model.fit(np.array(x_batch), np.array(y_batch), batch_size=len(x_batch), verbose=0)
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

# %%
num_runs = 1
run_rewards = []
env = gym.make('CartPole-v0')

for n in range(num_runs):
    print("Run {}.format(n)")
    ep_rewards = []
    num_episodes = 1000
    agent = DQNAgent(env, model)
    
    for ep in range(num_episodes):
        if ep > num_episodes - 2:
            agent.epsilon = 0.0
        state = agent.preprocess(env.reset())
        done = False
        i = 0
        total_reward = 0
        
        
        
    while not done:
        action = agent.choose_action(state, agent.get_epsilon(ep))
        next_state, reward, done, info = env.step(action)
        # env.render()
        next_state = agent.preprocess(next_state)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        i += 1
        total_reward += reward
        # time.sleep(0.03)
    ep_rewards.append(total_reward)
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
run_rewards.append(ep_rewards)
env.close()
for n, ep_rewards in enumerate(run_rewards):
  x = range(len(ep_rewards))
  cumsum = np.cumsum(ep_rewards)
  avgs = [cumsum[ep]/(ep+1) if ep<100 else (cumsum[ep]-cumsum[ep-100])/100 for ep in x]
  plt.plot(x, avgs)
plt.title("Agent Performance")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
print(x)

# %%
import tensorflow.compat.v1 as tf

class QNAgent():
    def __init__(self, env, buckets=(3, 3, 6, 6,), min_alpha=0.1, min_epsilon=0.1, gamma=1.0, ada_divisor=20):
        self.env = env # for choosing different environments
        self.buckets = buckets # down-scaling feature space to discrete range
        self.min_alpha = min_alpha # learning rate
        self.min_epsilon = min_epsilon # exploration rate
        self.gamma = gamma # discount factor
        self.ada_divisor = ada_divisor # decay rate parameter for alpha and epsilon
        self.build_model()
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        
    def build_model():
        tf.reset_default_graph()
        tf.disable_v2_behavior()
        # since we named a TensorFlow variable, reset graph before we define a model or else TensorFlow complains about redefining variables with duplicate names
        self.state_in = tf.placeholder(tf.int32, shape = [1])
        self.action_in = tf.placeholder(tf.int32, shape = [1])
        self.target_in = tf.placeholder(tf.float32, shape = [1])
        # define placeholders for the state and action indices as the inputs
        # and the target value used to calculate loss
        self.state = tf.one_hot(self.state_in, depth = self.state_size)
        self.action = tf.one_hot(self.action_in, depth = self.action_size)
        # convert input state and action index values to one-hot vector adding 2nd dimension giving depth to placeholder shape
        self.q_state = tf.layers.dense(self.state, units = self.action_size, name = "q_table")
        # from state vector pass to dense layer which outputs the row of Qvalues for the actions in the given state
        # we name the tensor to find the weights in the TensorFlow backend since they are the same values as the Qtable we want to print
        self.q_action = tf.reduce_sum(tf.multiply(self.q_state, self.action), axis = 1)
        # get Qvalue of given action through element-wise multiplication of the Qvalues with the one-hot action vector 
        # reduce it back to a single dimension vector
        self.loss = tf.reduce_sum(tf.square(self.target_in - self.q_action))
        # calculate loss as square diff of target and aprox Qvalue for the state-action pair, summed over the batch
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss)
        # optimizer to minimize loss at the specified learning rate
        
    # Discretizing input space to make Q-table and to reduce dimmensionality
    def discretize(self, state):
        upper_bounds = [self.env.observation_space.high[0], 0.5, self.env.observation_space.high[2], math.radians(50)]
        lower_bounds = [self.env.observation_space.low[0], -0.5, self.env.observation_space.low[2], -math.radians(50)]
        ratios = [(state[i] + abs(lower_bounds[i])) / (upper_bounds[i] - lower_bounds[i]) for i in range(len(state))]
        discretized_state = [int(round((self.buckets[i] - 1) * ratios[i])) for i in range(len(state))]
        discretized_state = [min(self.buckets[i] - 1, max(0, discretized_state[i])) for i in range(len(state))]
        return tuple(discretized_state)

    # Choosing action based on epsilon-greedy policy
    def choose_action(self, state, epsilon):
        q_state = self.sess.run(self.q_state, feed_dict = {self.state_in: [state]})
        # calculate state Qvalues by running the Q state operation by passing in the given state as a single element list to comply with our specified shape in the placeholder
        return self.env.action_space.sample() if (np.random.random() <= epsilon) else np.argmax(q_state)

    # Updating Q-value of state-action pair based on the Bellman equation
    def update_q(self, state, action, reward, next_state, alpha):
        self.Q[state][action] += alpha * (reward + self.gamma * np.max(self.Q[next_state]) - self.Q[state][action])

    # Reduce Exploration Rate Over time
    def get_epsilon(self, t):
        return max(self.min_epsilon, min(1, 1.0 - math.log10((t + 1) / self.ada_divisor)))

    # Reduce Learning Rate over time
    def get_alpha(self, t):
        return max(self.min_alpha, min(1.0, 1.0 - math.log10((t + 1) / self.ada_divisor)))

    def train(self, experience):
        # define train method for updating Qtable at each step
        state, action, next_state, reward, done = ([exp] for exp in experience)
        # takes the tuple of experience # NN implementation: wrap each value from the tuple in a list to comply with specified placeholder
        q_next = self.sess.run(self.q_state, feed_dict = {self.state_in: next_state})
        # calculate the next state's Qvalues
        q_next[done] = np.zeros([self.action_size]) # if done else q_next # non NN implementation
        # only non-terminal states have a next state so set Qvalues to 0 if next state is terminal
        # use list form [done] to set the value in the q_next list to zeros at the index where done is true
        q_target = reward + self.discount_rate * np.max(q_next)
        # calculate target value according to QLearning equation
        feed = {self.state_in: state, self.action_in: action, self.target_in: q_target}
        self.sess.run(self.optimizer, feed_dict = feed)
        # run optimizer passing in state action and target into the feed dictionary

    def __del__(self):
        # destructor
        self.sess.close()
        # close TensorFlow session

# %%
agent = QNAgent(env)
total_reward = 0
# to keep track of cumulative reward
for ep in range(100):
    # train over a number of episodes
    state = env.reset() 
    done = False
    while not done:  

        action = agent.get_action(state) 
        # call get_action() on agent; pass state as argument
        next_state, reward, done, info = env.step(action) 
        # apply action to environment; 
        # env.step() returns a tuple (list) with the next state, reward for last step, boolean for terminal episode, and info
        # episode termination conditions can be found in docu
        agent.train((state,action,next_state,reward,done))
        # call train method from agent passing the 5 values
        state = next_state
        # update state
        total_reward += reward
        # add reward 
        # env.render() 
        # render environment
        print("s:", state, 'a:', action)
        print("Episode {}, Total reward: {}, eps: {}".format(ep, total_reward, agent.eps))
        
        with tf.variable_scope("q_table", reuse = True):
        # activate the variable scope "q_table", reuse=True to include existing variables
            weights = agent.sess.run(tf.get_variable("kernel"))
            # get weight matrix from TensorFlow session (which is our q_table)
            print(weights)
          
        # print(agent.q_table) # non NN implementation
        # print Qtable for debugging
        # time.sleep(0.05) 
        # slows down env.render() to prevent crash
        clear_output(wait=True)
    env.close() 
    # close env after forloop ends to prevent crash with some gyms
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-05bd42f1e0bd> in <module>
# ----> 1 agent = QNAgent(env)
#       2 total_reward = 0
#       3 # to keep track of cumulative reward
#       4 for ep in range(100):
#       5     # train over a number of episodes
#
# <ipython-input-34-7e9c2955516a> in __init__(self, env, buckets, min_alpha, min_epsilon, gamma, ada_divisor)
#       9         self.gamma = gamma # discount factor
#      10         self.ada_divisor = ada_divisor # decay rate parameter for alpha and epsilon
# ---> 11         self.build_model()
#      12         self.sess = tf.Session()
#      13         self.sess.run(tf.global_variables_initializer())
#
# TypeError: build_model() takes 0 positional arguments but 1 was given

# %%
  
import gym
import math
import keras
import random
import numpy as np
from collections import deque
from  keras.models import  Sequential
from keras.layers import Dense
from keras.optimizers import Adam

max_score = 0

n_episodes = 5000
n_win_tick = 1000
max_env_steps = 1000

gamma = 1.0
epsilon = 1.0 #exploration
epsilon_min = 0.01
epsilon_decay = 0.999

alpha = 0.01 # learning rate
alpha_decay = 0.01
alpha_test_factor = 1.0

batch_size = 256
monitor = False
quiet = False

#environment Parameters
memory = deque(maxlen=100000)
env = gym.make('CartPole-v0')
if max_env_steps is not None:
    env._max_episode_steps = max_env_steps




# for i_episode in range(20):
#     observation = env.reset()
#     for t in range(100):
#         env.render()
#         action = env.action_space.sample()
#         observation, reward, done, info = env.step(action)
#         if done:
#             break


model = Sequential()
model.add(Dense(24,input_dim=4,activation='relu'))
model.add(Dense(48, activation='relu'))
model.add(Dense(96, activation='relu'))
model.add(Dense(48, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(2,activation='relu'))
model.compile(loss='mse', optimizer=Adam(lr=alpha, decay=alpha_decay))

#Define functions
def remember(state, action, reward, next_state, done):
    memory.append((state, action, reward, next_state, done))
def choose_action(state, epsilon):
    if np.random.random() <= epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(model.predict(state))
def get_epsilon(t):
    return max(epsilon_min, min(epsilon,1.0 - math.log10((t+1)*epsilon_decay)))
def preprocess(state):
    return np.reshape(state, [1,4])
def replay(batch_size,epsilon):
    x_batch, y_batch = [], []
    minibatch = random.sample(memory, min(len(memory), batch_size))
    for state, action, reward, next_state, done in minibatch:
        y_target = model.predict(state)
        y_target[0][action] = reward if done else reward + gamma * np.max(model.predict(next_state)[0])
        x_batch.append(state[0])
        y_batch.append(y_target[0])
    model.fit(np.array(x_batch), np.array(y_batch), batch_size=len(x_batch), verbose=0)
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay
# run function
def run():
    global max_score
    scores = deque(maxlen=100)
    for e in range(n_episodes):
        if e > n_episodes-2:
            global epsilon
            epsilon = 0.0
        state = preprocess(env.reset())
        done = False
        i = 0
        while not done:
            action = choose_action(state, get_epsilon(e))
            next_state, reward, done, _ = env.step(action)
            # env.render()
            next_state = preprocess(next_state)
            remember(state, action, reward, next_state, done)
            state = next_state
            i += 1
        if i > max_score:
            max_score = i
            # Save the weights
            model.save_weights(str(max_score) + 'model_weights.h5')

            # Save the model architecture
            with open(str(max_score) + 'model_architecture.json', 'w') as f:
                f.write(model.to_json())


        scores.append(i)
        mean_score = np.mean(scores)
        if mean_score >= n_win_tick and e >= 100:
            if not quiet: print("Ran " + str(e) + " episodes. Solved after " + str(e-100) + "trials")
            # Save the weights
            model.save_weights(str(max_score) + 'final_model_weights.h5')

            # Save the model architecture
            with open(str(max_score) + 'final_model_architecture.json', 'w') as f:
                f.write(model.to_json())

            return e-100
        if e % 100 == 0 and not quiet:
            print("episode " + str(e) + " mean survival time over last 100 episodes was " + str(mean_score) + " ticks")
        replay(batch_size, get_epsilon(e))
    if not quiet:
        print("did not solve after " + str(e) + " episodes")
    return e

#Training the network

run()

print("max achived score is : " + str(max_score))
# Out:
# episode 0 mean survival time over last 100 episodes was 33.0 ticks

# %%
class DQN:
    def __init__(self, model, env,
                 epsilon=0.5, epsilon_decay=0.995, epsilon_min=0.1,
                 gamma=0.995,
                 history_size=10000, epochs=10, train_size=10000, batch_size=256,
                 max_steps=5000,
                 log_every_n_steps=1,
                 evalutation_size=10,
                 target_score=500,
                 reward_func=None):
        """
        DQN - Reinforcement learning agent
        Parameters:
            model: model with fit() and predict() methods
            env: gym environment
            epsilon: probability of random actions
            epsilon_decay: decay of epsilon on the next training episode
            epsilon_min: minimum value of epsilon
            gamma: discount for the next state
            history_size: total number of stored observations among all episodes
            epochs: number of training epochs per episode
            train_size: number of obervations to train on after each episode
            batch_size: batch size for fit() method of the model
            max_steps: maximum number of steps in episode
            log_every_n_steps: output metrics every n steps
            evalutation_size: number of episodes in evaluations
            target_score: target score to finish when reached
            reward_func: function that transforms observations to rewards; use None for model-free RL
        """

        self.model = model
        self.env = env
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.gamma = gamma
        self.history_size = history_size
        self.epochs = epochs
        self.train_size = train_size
        self.batch_size = batch_size
        self.max_steps = max_steps
        self.log_every_n_steps = log_every_n_steps
        self.evalutation_size = evalutation_size
        self.target_score = target_score
        self.reward_func = reward_func

        self._epsilon = self.epsilon  # current epsilon
        self.history = deque(maxlen=self.history_size)
        self.scores = list()  # list of scores for each played episode

        assert self.model, "Model is not provided"
        model_methods = ("fit", "predict")
        for method_name in model_methods:
            assert callable(getattr(self.model, method_name, None)), "Invalid model: no %s() method" % method_name

        assert self.env, "Gym environment is not provided"
        model_methods = ("reset", "step", "render")
        for method_name in model_methods:
            assert callable(getattr(self.env, method_name, None)), "Invalid env: no %s() method" % method_name

        self.n_inputs = self.env.observation_space.shape[0]
        self.n_actions = self.env.action_space.n

        # columns offsets in a numpy row (see fit_one())
        self.STATE_idx = 0  # observation
        self.NEXT_STATE_idx = self.n_inputs  # next observation
        self.ACTION_idx = 2 * self.n_inputs
        self.DONE_idx = 2 * self.n_inputs + 1
        self.R_idx = 2 * self.n_inputs + 2
        self.MAXQ_idx = 2 * self.n_inputs + 3

    def get_action(self, observation):
        """
        Policy function: returns action for the given observation
        """

        return np.argmax(self.model.predict(observation.reshape(1,-1))[0])


    def fit_one(self):
        """
        Train the model on a single episode
        """

        score = 0
        observation = self.env.reset()
        done = False

        for _ in range(self.max_steps):
            if random.random() < self._epsilon:
                # explore - take random action
                action = self.env.action_space.sample()
            else:
                # exploit - take predicted action
                action = self.get_action(observation)

            next_observation, reward, done, info = self.env.step(action)

            if self.reward_func:  # redefine reward if reward_func is set
                reward_ = self.reward_func(next_observation)
            else:
                reward_ = reward

            # append row for further training
            self.history.append(list(observation) + list(next_observation) + \
                [action, done, reward_, 0] + [0] * self.n_actions)

            score += reward
            if done:
                break
            observation = next_observation

        # append last episode score to list of scores
        self.scores.append(score)

        # prepare training data:
        data = np.array(random.sample(self.history, min(self.train_size, len(self.history))))

        # predict max(Q'):
        data[:, self.MAXQ_idx] = np.max(self.model.predict(data[:, self.NEXT_STATE_idx:self.NEXT_STATE_idx+self.n_inputs]), axis=1)

        # predict Q:
        data[:, -self.n_actions:] = self.model.predict(data[:, :self.n_inputs])

        for i in range(self.n_actions):
            # Q(s,a) = r + gamma * max(Q(s',a'))
            data[data[:, self.ACTION_idx] == i, -self.n_actions+i] = \
                data[data[:, self.ACTION_idx] == i, self.R_idx] + \
                self.gamma * data[data[:, self.ACTION_idx] == i, self.MAXQ_idx]

            # set Q(s,a) to 1 if done:
            data[(data[:, self.DONE_idx] == 1) & (data[:, self.ACTION_idx] == i), -self.n_actions + i] = 1

        self.model.fit(
            data[:, :self.n_inputs],
            data[:, -self.n_actions:],
            batch_size=self.batch_size,
            epochs=10,
            verbose=0)
        self._epsilon = max(self.epsilon_min, self._epsilon*self.epsilon_decay)

    def fit(self, episodes=2000):
        """
        Fit the model
        """

        for i in range(1, episodes + 1):
            self.fit_one()
            
            if i % self.log_every_n_steps==0:
                score = self.evaluate()
                print("Episode %i/%i: avg. score=%.1f, epsilon=%.2f, history_size=%i, train_size=%i" % (
                    i, episodes, score, self._epsilon, len(self.history), min(self.train_size, len(self.history))))
                if score >= self.target_score:
                    print("Target score achieved: target=%.1f, actual=%.1f" % (self.target_score, score))
                    return

        print("Target score is not reached")

    def evaluate(self, render_games=1):
        """
        Evaluate the model's performance without random actions
        render_games: number of games withing evaluation_size to render on screen
        """

        scores = list()
        for _ in range(self.evalutation_size):
            score = 0
            observation = self.env.reset()

            for j in range(self.max_steps):
                if _ < render_games:  # render only `render_games` episodes
                    # self.env.render()
                    action = self.get_action(observation)
                next_observation, reward, done, info = self.env.step(action)
                score += reward
                if done: break
                observation = next_observation
            scores.append(score)
        return np.mean(scores)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

env = gym.make('CartPole-v1')
n_inputs = env.observation_space.shape[0]
n_actions = env.action_space.n
max_theta = env.observation_space.high[2]
def cartpole_reward(observation):
    return max_theta - abs(observation[2])

# create model
model = Sequential()
model.add(Dense(units=24, activation="tanh", input_dim=n_inputs))
model.add(Dense(units=24, activation="tanh"))
model.add(Dense(units=n_actions, activation="linear"))
model.compile(loss="mse", optimizer=Adam(lr=0.1, decay=0.03))
agent = DQN(model, env)
start = time.time()
agent.fit()
print("Elapsed time: %.1f seconds" % (time.time()-start))
